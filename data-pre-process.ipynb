# %% [markdown]
# # Pre-process data folder
#
# Collect the information in "/Data" (or "/Data-snapshot" for the illustration) to generate the data to feed the evaluation. Collect the market information to describe the environment. Save the data for investments factor calculation in a pandas dataframe.
#
# Presentation of the dataset then:
#  - Collection of the dataset for valuation of portfolio - (just the closing price of equities is required.)
#  - Collection of the dataset for selection and factor construction - (price and other market information like equities debt, fx, commodities, equity index, etc)
#  - Save the data that is collected into pansdas dataframes.
#
# COMMENT: "ISIN" defines the mnemonic to identify equities like isin="US4581401001" defines INTEL. Thus, isin and equity code refer to the same meaning.
#
# Output in folder 'Data-processed':
# * File of the time-series  = 'data_content.csv'
# * File of the static definitions = 'data_risk.csv'
# * File of the stock closing price = 'data_list.csv'

# %% [markdown]
# ## 1. load the libraries

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

import numpy as np
import pandas as pd
import os

# %% [markdown]
# ##  2. Constants
#
# Define Date as "YYYY-MM-DD" for end and start calculation - 10 year time-frame is considered consistent with years pre and post 2008 financial crisis)
#
# NB: Post 2008 crisis is a single regime since that corresponds to the longest stock rally and therefore good strategies would be skewed towards getting exposure to risk, i.e. growth stocks.

# %%
DATE_MIN = "01/01/2004"  # Date minimum at which the evaluation starts. (Should contain the train/dev/text sets)
DATE_MAX = "01/01/2014"  # Date maximum at which the evaluation end.

# %%
# Data description for asset classes (Equities, Indices, FX, Commodities, etc)
equities = "Equities Datastream Data Identifier_Cleaned.xls"
equities_indices = "Equities Indices Data Identifier_Cleaned.xls"
fx = "Exchange Rate Data Identifier_Cleaned.xls"
commodities = "Commodities Data Identifier_Cleaned.xls"
economic = "Economics Data Identifier_Cleaned.xls"
futures = "Futures Data Identifier_Cleaned.xls"
interest_rate = "Interest Rates Data Identifier_Cleaned.xls"
options = "Options Data Identifier_Cleaned.xls"

# %%
def print_codes(label):
    """
    Helper function to obtain the description of dataset per asset classes - ie
    options, equities, equities_indices, fx, commodities, economic, futures, interest_rate
    """
    name= pd.read_excel(os.path.join(os.getcwd(),"Data","Description","Data Type",label))
    name = name[['Name','Symbol','Type']]
    return name[name['Type']== 'Time Series'] , name[name['Type']== 'Static']

# Example of labels for stocks options
timeseries, static = print_codes(options)
# timeseries, static = print_codes(equities)
# timeseries, static = print_codes(equities_indices)
# timeseries, static = print_codes(fx)
# timeseries, static = print_codes(commodities)
# timeseries, static = print_codes(economic)
# timeseries, static = print_codes(futures)
# timeseries, static = print_codes(interest_rate)

# %%
# Illustration of data: time-series type of data (here: equities options)
timeseries.loc[:200, ['Name','Symbol']].set_index('Symbol').to_dict()
# Out:
# {'Name': {u'DZ': u'Delta',
#   u'FV': u'Fair Value',
#   u'GM': u'Gamma',
#   u'I2': u'Implied Volatility - 2 Year Constant Maturity (Cont Series)',
#   u'I3': u'Implied Volatility - 3 Year Constant Maturity (Cont Series)',
#   u'I4': u'Implied Volatility - 4 Year Constant Maturity (Cont Series)',
#   u'I5': u'Implied Volatility - 5 Year Constant Maturity (Cont Series)',
#   u'MP': u'Price - Market',
#   u'O1': u'Implied Volatility - 1 Month Constant Maturity (Cont Series)',
#   u'O2': u'Implied Volatility - 2 Month Constant Maturity (Cont Series)',
#   u'O3': u'Implied Volatility - 3 Month Constant Maturity (Cont Series)',
#   u'O6': u'Implied Volatility - 6 Month Constant Maturity (Cont Series)',
#   u'OC': u'Implied Volatility - Spot - Week Constant Maturity (Cont Series)',
#   u'OD': u'Implied Volatility - 1 Week Constant Maturity (Cont Series)',
#   u'OI': u'Open Interest',
#   u'OM': u'At The Money Option Price (Cont Series)',
#   u'ON': u'Implied Volatility - 9 Month Constant Maturity (Cont Series)',
#   u'OS': u'At The Money Strike Price (Cont Series)',
#   u'OU': u'Underlying Price (Cont Series)',
#   u'OUP': u'Underlying Series Price (Single Series)',
#   u'OV': u'Implied Volatility - At The Money Nearest Strike (Cont Series)',
#   u'OY': u'Implied Volatility - 1 Year Constant Maturity (Cont Series)',
#   u'P': u'Price (Adjusted - Default)',
#   u'PA': u'Price - Ask',
#   u'PB': u'Price - Bid',
#   u'PH': u'Price - Intraday High',
#   u'PL': u'Price - Intraday Low',
#   u'PO': u'Price - Opening',
#   u'TA': u'Theta (Single Series)',
#   u'VG': u'Vega, Kappa',
#   u'VI': u'Implied Volatility - At The Money Interpolated (Cont Series)',
#   u'VL': u'Implied Volatility (Single Series)',
#   u'VM': u'Volume of Contracts Traded',
#   u'VX': u'Implied Volatility - Trade Weighted (Cont Series)'}}

# %%
# Illustration of data: Static type of data  - Typically description of financial instruments (here: equities options)
static.loc[0:100, ['Name','Symbol']].set_index('Symbol').to_dict()
# Out:
# {'Name': {u'MNEM': u'Mnemonic',
#   u'NAME': u'Name',
#   u'OEX': u'Exchange',
#   u'OEXT': u'Expiry Style',
#   u'OLOT': u'Lot Size (Single Series)',
#   u'OPMOD': u'Option Model Calculation',
#   u'OPTCODE': u'Exchange Ticker Symbol',
#   u'OPTYPE': u'Option Underlying Instrument Type',
#   u'OTYP': u'Option Type (Single Series)',
#   u'OUI': u'Underlying Series Mnemonic',
#   u'OUN': u'Underlying Series Name (Single Series)',
#   u'OXCP': u'Exercise Price (Single Series)',
#   u'OXPD': u'Expiry Date (Single Series)',
#   u'PCUR': u'Price - Currency',
#   u'TCYCLE': u'Trading Cycle',
#   u'TIME': u'Time - Latest Value',
#   u'TYPE': u'Type Of Instrument'}}

# %% [markdown]
# ##  3. Selected data to collect
#
# illustration fist of the financial information for equities and then illustration of the equities options information

# %% [raw]
# # Liste of the corporate Finance Data available.
#
# Code - Description
# --------------------------------
# WC01001  	NET SALES OR REVENUES
# WC01001  	NET SALES OR REVENUES
# WC01002  	PREMIUMS EARNED
# WC01016  	INTEREST INCOME - TOTAL
# WC01051  	COST OF GOODS SOLD (EXCL DEPRECIATION)
# WC01075  	INTEREST EXPENSE - TOTAL
# WC01076  	NET INTEREST INCOME
# WC01084  	SALARIES AND BENEFITS EXPENSES
# WC01100  	GROSS INCOME
# WC01101  	SELLING, GENERAL & ADMINISTRATIVE EXPENSES
# WC01149  	AMORTIZATION OF INTANGIBLES
# WC01150  	AMORTIZATION OF DEFERRED CHARGES
# WC01151  	DEPRECIATION, DEPLETION AND AMORTIZATION
# WC01201  	RESEARCH & DEVELOPMENT
# WC01250  	OPERATING INCOME
# WC01251  	INTEREST EXPENSE ON DEBT
# WC01253  	EXTRAORDINARY CREDIT - PRETAX
# WC01254  	EXTRAORDINARY CHARGE - PRETAX
# WC01255  	INTEREST CAPITALIZED
# WC01266  	NON-OPERATING INTEREST INCOME
# WC01271  	PROVISION FOR LOAN LOSSES
# WC01401  	PRETAX INCOME
# WC01451  	INCOME TAXES
# WC01501  	MINORITY INTEREST
# WC01551  	NET INCOME BEFORE EXTRA ITEMS/PREFERRED DIVIDENDS
# WC01601  	EXTRA ITEMS & GAIN/LOSS SALE OF ASSETS
# WC01701  	PREFERRED DIVIDEND REQUIREMENTS
# WC01705  	NET INCOME USED TO CALCULATE DILUTED EARNINGS PER SHARE
# WC01706  	NET INCOME USED TO CALCULATE BASIC EARNINGS PER SHARE
# WC01751  	NET INCOME AVAILABLE TO COMMON
# WC02001  	CASH & SHORT TERM INVESTMENTS
# WC02003  	CASH
# WC02004  	CASH & DUE FROM BANKS
# WC02051  	RECEIVABLES(NET)
# WC02101  	INVENTORIES - TOTAL
# WC02201  	CURRENT ASSETS - TOTAL
# WC02255  	INVESTMENTS - TOTAL
# WC02276  	LOANS - NET
# WC02501  	PROPERTY, PLANT AND EQUIPMENT - NET
# WC02649  	TOTAL INTANGIBLE OTHER ASSETS - NET
# WC02999  	TOTAL ASSETS
# WC03019  	DEPOSITS - TOTAL
# WC03030  	INSURANCE RESERVES - TOTAL
# WC03040  	ACCOUNTS PAYABLE
# WC03051  	SHORT TERM DEBT & CURRENT PORTION OF LONG TERM DEBT
# WC03101  	CURRENT LIABILITIES - TOTAL
# WC03151  	WORKING CAPITAL
# WC03251  	LONG TERM DEBT
# WC03255  	TOTAL DEBT
# WC03263  	DEFERRED TAXES
# WC03426  	MINORITY INTEREST
# WC03451  	PREFERRED STOCK
# WC03480  	COMMON STOCK
# WC03501  	COMMON EQUITY
# WC03998  	TOTAL CAPITAL
# WC04050  	AMORTIZATION OF INTANGIBLE ASSETS
# WC04201  	FUNDS FROM OPERATIONS
# WC04251  	NET PROCEEDS FROM SALE/ISSUE OF COMMON & PREFERRED
# WC04551  	CASH DIVIDENDS PAID - TOTAL
# WC04601  	CAPITAL EXPENDITURES (ADDITIONS TO FIXED ASSETS)
# WC04851  	INCREASE/DECREASE IN CASH AND SHORT TERM INVESTMENTS
# WC04860  	NET CASH FLOW - OPERATING ACTIVITIES
# WC04870  	NET CASH FLOW - INVESTING
# WC04890  	NET CASH FLOW - FINANCING
# WC05350  	DATE OF FISCAL YEAR END
# WC05376  	COMMON DIVIDENDS (CASH)
# WC06026  	NATION
# WC07011  	EMPLOYEES
# WC08101  	QUICK RATIO
# WC08106  	CURRENT RATIO
# WC08126  	INVENTORIES - DAYS HELD
# WC08131  	ACCOUNTS RECEIVABLES DAYS
# WC08221  	TOTAL DEBT % TOTAL CAPITAL & SHORT TERM DEBT
# WC08231  	TOTAL DEBT % COMMON EQUITY
# WC08301  	RETURN ON EQUITY - TOTAL (%)
# WC08311  	CASH FLOW/SALES
# WC08316  	OPERATING PROFIT MARGIN
# WC08321  	PRETAX MARGIN
# WC08366  	NET MARGIN
# WC08376  	RETURN ON INVESTED CAPITAL
# WC18191  	EARNINGS BEFORE INTEREST AND TAXES (EBIT)
# WC18192  	DIVIDENDS PROVIDED FOR OR PAID - COMMON
# WC18198  	EBIT & DEPRECIATION

# %% [raw]
# # Liste of the continuous stock options data available:
#
# Description - CODE - type (Time Series  or Static)
# -------------------------------------------------
# Implied Volatility (Single Series)	VL	Time Series
# Price - Market	MP	Time Series
# Implied Volatility - At The Money Interpolated (Cont Series)	VI	Time Series
# Open Interest	OI	Time Series
# Volume of Contracts Traded	VM	Time Series
# Delta	DZ	Time Series
# Underlying Price (Cont Series)	OU	Time Series
# Exercise Price (Single Series)	OXCP	Static
# Expiry Date (Single Series)	OXPD	Static
# Price - Intraday High	PH	Time Series
# Price - Intraday Low	PL	Time Series
# Price - Opening	PO	Time Series
# Underlying Series Price (Single Series)	OUP	Time Series
# At The Money Option Price (Cont Series)	OM	Time Series
# At The Money Strike Price (Cont Series)	OS	Time Series
# Exchange	OEX	Static
# Exchange Ticker Symbol	OPTCODE	Static
# Expiry Style	OEXT	Static
# Fair Value	FV	Time Series
# Gamma	GM	Time Series
# Implied Volatility - 1 Month Constant Maturity (Cont Series)	O1	Time Series
# Implied Volatility - 1 Week Constant Maturity (Cont Series)	OD	Time Series
# Implied Volatility - 1 Year Constant Maturity (Cont Series)	OY	Time Series
# Implied Volatility - 2 Month Constant Maturity (Cont Series)	O2	Time Series
# Implied Volatility - 2 Year Constant Maturity (Cont Series)	I2	Time Series
# Implied Volatility - 3 Month Constant Maturity (Cont Series)	O3	Time Series
# Implied Volatility - 3 Year Constant Maturity (Cont Series)	I3	Time Series
# Implied Volatility - 4 Year Constant Maturity (Cont Series)	I4	Time Series
# Implied Volatility - 5 Year Constant Maturity (Cont Series)	I5	Time Series
# Implied Volatility - 6 Month Constant Maturity (Cont Series)	O6	Time Series
# Implied Volatility - 9 Month Constant Maturity (Cont Series)	ON	Time Series
# Implied Volatility - At The Money Nearest Strike (Cont Series)	OV	Time Series
# Implied Volatility - Spot - Week Constant Maturity (Cont Series)	OC	Time Series
# Implied Volatility - Trade Weighted (Cont Series)	VX	Time Series
# Lot Size (Single Series)	OLOT	Static
# Mnemonic	MNEM	Static
# Name	NAME	Static
# Option Model Calculation	OPMOD	Static
# Option Type (Single Series)	OTYP	Static
# Option Underlying Instrument Type	OPTYPE	Static
# Price (Adjusted - Default)	P	Time Series
# Price - Ask	PA	Time Series
# Price - Bid	PB	Time Series
# Price - Currency	PCUR	Static
# Theta (Single Series)	TA	Time Series
# Time - Latest Value	TIME	Static
# Trading Cycle	TCYCLE	Static
# Type Of Instrument	TYPE	Static
# Underlying Series Mnemonic	OUI	Static
# Underlying Series Name (Single Series)	OUN	Static
# Vega, Kappa	VG	Time Series

# %% [markdown]
# ###  3.1 Dictionnaires per asset class of the information collected

# %%
# Equities data - Time Series and Static
EQUITY_DEF = {u'P': u'Price (Adjusted - Default)',
              u'PH': u'Price - Intraday High',
              u'PL': u'Price - Intraday Low',
              u'PO': u'Price - Opening', 
              u'MVC':u'Market Value For Company'}
EQUITY_STATIC = {u'ISIN': u'Code - Isin',
                 u'NAME': u'Name'}
# Equities data - used for position computation - only closing price required
RISK_DEF = {u'P': u'Price (Adjusted - Default)'}

# %%
# Time-series data of financial information for equities
CORPORATE_DEF = {"WC08101":"QUICK RATIO",                                            
                 "WC08106":"CURRENT RATIO",  
                 "WC03051":"SHORT TERM DEBT & CURRENT PORTION OF LONG TERM DEBT",
                 "WC08311":"CASH FLOW/SALES",
                 "WC08316":"OPERATING PROFIT MARGIN",
                 "WC08221":"TOTAL DEBT % TOTAL CAPITAL & SHORT TERM DEBT",       
                 "WC08231":"TOTAL DEBT % COMMON EQUITY",
                 "WC18191":"EARNINGS BEFORE INTEREST AND TAXES (EBIT)",
                 "WC05376":"COMMON DIVIDENDS (CASH)",
                 "WC02999":"TOTAL ASSETS",
                 "WC01151":"DEPRECIATION, DEPLETION AND AMORTIZATION",
                 "WC03255":"TOTAL DEBT",
                 "WC02001":"CASH"}

# %%
# Continuous Options data for equities

# Comment: Continious options are instruments that represent the evolution of the different options for a unique
# derlying instruments. It avoids looping on all options quoted for that instrument.
CONTINUOUS_OPTION_DEF = {
    "MP":"Price - Market",
    "VI":"Implied Volatility - At The Money Interpolated (Cont Series)",
    "OI":"Open Interest",
    "VM":"Volume of Contracts Traded",
    "OD":"Implied Volatility - 1 Week Constant Maturity (Cont Series)",
    "O1":"Implied Volatility - 1 Month Constant Maturity (Cont Series)",
    "O3": "Implied Volatility - 3 Month Constant Maturity (Cont Series)",
    "O6": "Implied Volatility - 6 Month Constant Maturity (Cont Series)",
    "ON":"Implied Volatility - 9 Month Constant Maturity (Cont Series)",
    "OY":"Implied Volatility - 1 Year Constant Maturity (Cont Series)",
    "I3":"Implied Volatility - 3 Year Constant Maturity (Cont Series)"}

CONTINUOUS_OPTION_STATIC = {"MNEM": "Mnemonic",
                            "NAME":"Name",
                            "OPTYPE":"Option Underlying Instrument Type"}

# %% [raw]
# # NOT COLLECTED AT THE MOMEMT: Stock Options data - Time Series and Static
# OP_DEF = {u'P': u'Price (Adjusted - Default)',
#           u'PH': u'Price - Intraday High',
#           u'PL': u'Price - Intraday Low',
#           u'PO': u'Price - Opening',
#           u'OU': u'Underlying Price (Cont Series)',
#           u'OI': u'Open Interest',
#           u'O1': u'Implied Volatility - 1 Month Constant Maturity (Cont Series)',
#           u'O2': u'Implied Volatility - 2 Month Constant Maturity (Cont Series)',
#           u'O3': u'Implied Volatility - 3 Month Constant Maturity (Cont Series)',
#           u'O6': u'Implied Volatility - 6 Month Constant Maturity (Cont Series)',
#           u'VI': u'Implied Volatility - At The Money Interpolated (Cont Series)',
#           u'VM': u'Volume of Contracts Traded'}
#
# OP_STATIC = {u'MNEM': u'Mnemonic',
#              u'NAME': u'Name',
#              u'OEXT': u'Expiry Style',
#              u'OXCP': u'Exercise Price (Single Series)',
#              u'OXPD': u'Expiry Date (Single Series)',
#              u'PCUR': u'Price - Currency',
#              u'OTYP': u'Option Type (Single Series)',
#              u'OUI': u'Underlying Series Mnemonic',
#              u'TYPE': u'Type Of Instrument'}

# %%
# Interest Rate data - Time Series and Static
IR_DEF = {u'IR': u'Interest Rate'}
IR_STATIC = {u'MNEM': u'Mnemonic',u'NAME': u'Name',u'TYPE': u'Type Of Instrument'}

# %% [raw]
# # NOT COLLECTED AT THE MOMEMT:  Futures contract - Time Series and Static
# FUT_DEF = {u'PS': u'Settlement Price',
#            u'PH': u'Price - Intraday High',
#            u'PL': u'Price - Intraday Low',
#            u'PO': u'Price - Opening',
#            u'VM': u'Volume of Contracts Traded'}
# FUT_STATIC = {u'MNEM': u'Mnemonic',
#               u'NAME': u'Name',
#               u'FUTBDATE': u'Start Date (Futures)',
#               u'FUI': u'Underlying Instrument',
#               u'STDT': u'Settlement Date'}

# %%
# Economic indictors data - Time Series and Static
ECO_DEF = {u'ES': u'Economic Series - Weekly'}
ECO_STATIC = {u'MNEM': u'Mnemonic',
              u'NAME': u'Name',
              u'TYPE': u'Type Of Instrument'}

# %%
# Commodities data - Time Series and Static
COMMO_DEF = {u'PO': u'Price - Opening',
             u'PH': u'Price - Intraday High',
             u'PL': u'Price - Intraday Low',
             u'P': u'Price (Adjusted - Default)'}
COMMO_STATIC = {u'MNEM': u'Mnemonic', u'NAME': u'Name'}

# %%
# Equity indices data - Time Series and Static
EQTYIND_DEF = {u'P': u'Price (Adjusted - Default)',
               u'PH': u'Price - Intraday High',
               u'PL': u'Price - Intraday Low',
               u'PO': u'Price - Opening'}
EQTYIND_STATIC = {u'ISIN': u'Code - Isin', u'NAME': u'Name'}

# %%
# Currencies data - Time Series and Static
FX_DEF = {u'ER': u'Exchange Rate - Middle'}
FX_STATIC = {u'MNEM': u'Mnemonic',
             u'NAME': u'Name',
             u'SICUR': u'Currency'}

# %% [markdown]
# ##  4. Collect the data
#
# Aggregate the different files of the financial instruments from DataStream (Reuters Financial) filtered with the information of interest through the previous dictionnaries (i.e. FX_DEF)
#
# ###  4.1 Time Series data
#
# __Helper Functions__

# %%
 def process_df(path, filename, variable_isin):
    """
    Collect the variables in variable_isin for a isin in filename and output it into a pandas dataframe. 
    """
    test = pd.read_csv(os.path.join(path,filename), sep=";",
                       header=0,parse_dates=[0],infer_datetime_format=True,  encoding="utf-8")
    Col = list(test.columns)
    isin = Col[0]
    Col[0] = 'Date'
    test.columns = Col
    listcode = list(variable_isin)
    listcode.append('Date')
    test.drop(set(test.columns).difference(set(listcode)),axis=1, inplace=True) 
    test.columns = [isin + "-" + i for i in (test.columns)]
    test.set_index(isin + "-" +'Date', inplace=True)
    test.index.name = 'Date'
    return test.loc[(test.index > DATE_MIN) & (test.index < DATE_MAX)].dropna()

def collection(path_in, list_isin, variable_isin, cumul_df=None, first_df=True):
    """
    Process each of the codes (i.e. isin) to collect the data
    """
    source_path = os.path.join(os.getcwd(),*path_in)
    for position,filename in enumerate(list_isin):
        code_to_keep = variable_isin  # To avoid append "Date" at each computation
        if first_df:
            return process_df(source_path, filename, variable_isin)
        if position > 0:
            cumul_df = cumul_df.join(process_df(source_path, filename, variable_isin))
    return cumul_df

# %% [markdown]
# __Collect the data for time series__

# %%
# Collect the equities
def collect_ts(isin, variable):
    """
    Function to process a type of instruments and all the isin code given
    """
    df_collect = collection(['Data-snapshot','US Stocks'],isin, variable)
    return collection(['Data-snapshot','US Stocks'],isin, variable,df_collect, False)

# List of the equities - isin
list_isin = ['PA1436583006.txt',
             'US22160K1051.txt',
             'US4581401001.txt',
             'AN8068571086.txt']

collect_ts(list_isin, EQUITY_DEF.keys()).head()
# Out:
# /Users/pierrenowicki/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:15: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   from ipykernel import kernelapp as app
#             PA1436583006-MVC  PA1436583006-P  PA1436583006-PH  \
# Date
# 2004-01-02          33610.74           39.82            40.25
# 2004-01-05          34121.62           40.43            40.61
# 2004-01-06          34297.64           40.75            40.80
# 2004-01-07          34380.14           40.83            41.00
# 2004-01-08          34754.78           41.24            41.30
#
#             PA1436583006-PL  PA1436583006-PO  US22160K1051-MVC  \
# Date
# 2004-01-02           39.750            39.91          16637.42
# 2004-01-05           40.185            40.28          16559.55
# 2004-01-06           40.300            40.43          16747.36
# 2004-01-07           40.550            40.70          16985.55
# 2004-01-08           40.850            40.87          17068.01
#
#             US22160K1051-P  US22160K1051-PH  US22160K1051-PL  US22160K1051-PO  \
# Date
# 2004-01-02           36.32           37.420            36.18            37.19
# 2004-01-05           36.15           36.610            35.86            36.44
# 2004-01-06           36.56           36.930            36.06            36.10
# 2004-01-07           37.08           37.175            36.52            36.58
# 2004-01-08           37.26           37.530            37.02            37.40
#
#             US4581401001-MVC  US4581401001-P  US4581401001-PH  \
# Date
# 2004-01-02          210068.9           32.16           32.600
# 2004-01-05          214967.9           32.91           32.970
# 2004-01-06          214902.7           32.90           33.000
# 2004-01-07          222022.5           33.99           34.000
# 2004-01-08          223655.6           34.24           34.349
#
#             US4581401001-PL  US4581401001-PO  AN8068571086-MVC  \
# Date
# 2004-01-02            32.03            32.36          32027.91
# 2004-01-05            32.40            32.52          32525.97
# 2004-01-06            32.62            32.92          32174.39
# 2004-01-07            33.22            33.33          31377.51
# 2004-01-08            33.90            34.17          31553.29
#
#             AN8068571086-P  AN8068571086-PH  AN8068571086-PL  AN8068571086-PO
# Date
# 2004-01-02          27.330           27.550           27.230           27.360
# 2004-01-05          27.755           27.780           26.990           27.100
# 2004-01-06          27.455           27.955           27.275           27.775
# 2004-01-07          26.775           27.330           26.645           27.330
# 2004-01-08          26.925           27.040           26.390           26.500

# %%
# Process the equity
list_isin = ['PA1436583006.txt',
             'US22160K1051.txt',
             'US4581401001.txt',
             'AN8068571086.txt']
variable_isin = EQUITY_DEF.keys()

collect_eq = collection(['Data-snapshot','US Stocks'],
           list_isin, variable_isin)
collect_eq = collection(['Data-snapshot','US Stocks'],
           list_isin, variable_isin,collect_eq, False)
collect_eq.head()
# Out:
# /Users/pierrenowicki/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2878: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             PA1436583006-MVC  PA1436583006-P  PA1436583006-PH  \
# Date
# 2004-01-02          33610.74           39.82            40.25
# 2004-01-05          34121.62           40.43            40.61
# 2004-01-06          34297.64           40.75            40.80
# 2004-01-07          34380.14           40.83            41.00
# 2004-01-08          34754.78           41.24            41.30
#
#             PA1436583006-PL  PA1436583006-PO  US22160K1051-MVC  \
# Date
# 2004-01-02           39.750            39.91          16637.42
# 2004-01-05           40.185            40.28          16559.55
# 2004-01-06           40.300            40.43          16747.36
# 2004-01-07           40.550            40.70          16985.55
# 2004-01-08           40.850            40.87          17068.01
#
#             US22160K1051-P  US22160K1051-PH  US22160K1051-PL  US22160K1051-PO  \
# Date
# 2004-01-02           36.32           37.420            36.18            37.19
# 2004-01-05           36.15           36.610            35.86            36.44
# 2004-01-06           36.56           36.930            36.06            36.10
# 2004-01-07           37.08           37.175            36.52            36.58
# 2004-01-08           37.26           37.530            37.02            37.40
#
#             US4581401001-MVC  US4581401001-P  US4581401001-PH  \
# Date
# 2004-01-02          210068.9           32.16           32.600
# 2004-01-05          214967.9           32.91           32.970
# 2004-01-06          214902.7           32.90           33.000
# 2004-01-07          222022.5           33.99           34.000
# 2004-01-08          223655.6           34.24           34.349
#
#             US4581401001-PL  US4581401001-PO  AN8068571086-MVC  \
# Date
# 2004-01-02            32.03            32.36          32027.91
# 2004-01-05            32.40            32.52          32525.97
# 2004-01-06            32.62            32.92          32174.39
# 2004-01-07            33.22            33.33          31377.51
# 2004-01-08            33.90            34.17          31553.29
#
#             AN8068571086-P  AN8068571086-PH  AN8068571086-PL  AN8068571086-PO
# Date
# 2004-01-02          27.330           27.550           27.230           27.360
# 2004-01-05          27.755           27.780           26.990           27.100
# 2004-01-06          27.455           27.955           27.275           27.775
# 2004-01-07          26.775           27.330           26.645           27.330
# 2004-01-08          26.925           27.040           26.390           26.500

# %%
# Process the equity for risk position calculus - P&L
list_isin = ['PA1436583006.txt',
             'US22160K1051.txt',
             'US4581401001.txt',
             'AN8068571086.txt']

variable_isin = RISK_DEF.keys()

collect_risk = collection(['Data-snapshot','US Stocks'],
           list_isin, RISK_DEF.keys())
collect_risk = collection(['Data-snapshot','US Stocks'],
           list_isin, RISK_DEF.keys(),collect_risk, False)
collect_risk.head()
# Out:
#             PA1436583006-P  US22160K1051-P  US4581401001-P  AN8068571086-P
# Date
# 2004-01-02           39.82           36.32           32.16          27.330
# 2004-01-05           40.43           36.15           32.91          27.755
# 2004-01-06           40.75           36.56           32.90          27.455
# 2004-01-07           40.83           37.08           33.99          26.775
# 2004-01-08           41.24           37.26           34.24          26.925

# %%
# Process the equity for corporate finance
list_isin = ['PA1436583006.txt',
             'US22160K1051.txt',
             'US4581401001.txt',
             'AN8068571086.txt']
variable_isin = CORPORATE_DEF.keys()

collect_corp = collection(['Data-snapshot','US Stocks'],
           list_isin, CORPORATE_DEF.keys())
collect_corp = collection(['Data-snapshot','US Stocks'],
           list_isin, CORPORATE_DEF.keys(),collect_corp, False)
collect_corp.head()
# Out:
#             PA1436583006-WC01151  PA1436583006-WC02001  PA1436583006-WC02999  \
# Date
# 2004-01-05              812000.0              660000.0            27636000.0
# 2004-01-12              812000.0              660000.0            27636000.0
# 2004-01-19              812000.0              660000.0            27636000.0
# 2004-01-26              812000.0              660000.0            27636000.0
# 2004-02-02              812000.0              660000.0            27636000.0
#
#             PA1436583006-WC03051  PA1436583006-WC03255  PA1436583006-WC05376  \
# Date
# 2004-01-05             1662000.0             7953000.0              400000.0
# 2004-01-12             1662000.0             7953000.0              400000.0
# 2004-01-19             1662000.0             7953000.0              400000.0
# 2004-01-26             1662000.0             7953000.0              400000.0
# 2004-02-02             1662000.0             7953000.0              400000.0
#
#             PA1436583006-WC08101  PA1436583006-WC08106  PA1436583006-WC08221  \
# Date
# 2004-01-05                  0.21                  0.34                 33.54
# 2004-01-12                  0.21                  0.34                 33.54
# 2004-01-19                  0.21                  0.34                 33.54
# 2004-01-26                  0.21                  0.34                 33.54
# 2004-02-02                  0.21                  0.34                 33.54
#
#             PA1436583006-WC08231  ...  AN8068571086-WC03051  \
# Date                              ...
# 2004-01-05                 50.46  ...              716000.0
# 2004-01-12                 50.46  ...              716000.0
# 2004-01-19                 50.46  ...              716000.0
# 2004-01-26                 50.46  ...              716000.0
# 2004-02-02                 50.46  ...              716000.0
#
#             AN8068571086-WC03255  AN8068571086-WC05376  AN8068571086-WC08101  \
# Date
# 2004-01-05             4660052.0              441219.0                   1.2
# 2004-01-12             4660052.0              441219.0                   1.2
# 2004-01-19             4660052.0              441219.0                   1.2
# 2004-01-26             4660052.0              441219.0                   1.2
# 2004-02-02             4660052.0              441219.0                   1.2
#
#             AN8068571086-WC08106  AN8068571086-WC08221  AN8068571086-WC08231  \
# Date
# 2004-01-05                   1.5                 41.63                 76.18
# 2004-01-12                   1.5                 41.63                 76.18
# 2004-01-19                   1.5                 41.63                 76.18
# 2004-01-26                   1.5                 41.63                 76.18
# 2004-02-02                   1.5                 41.63                 76.18
#
#             AN8068571086-WC08311  AN8068571086-WC08316  AN8068571086-WC18191
# Date
# 2004-01-05                  21.9                 14.19             1442000.0
# 2004-01-12                  21.9                 14.19             1442000.0
# 2004-01-19                  21.9                 14.19             1442000.0
# 2004-01-26                  21.9                 14.19             1442000.0
# 2004-02-02                  21.9                 14.19             1442000.0
#
# [5 rows x 52 columns]

# %%
# Process the equities indicies
list_isin = ['NASA100.txt',
             'NASCOMP.txt',
             'S&PCOMP.txt',
             'CBOEVIX.txt']
variable_isin = EQTYIND_DEF.keys()

collect_eqind = collection(['Data-snapshot','Index'],
           list_isin, EQTYIND_DEF.keys())
collect_eqind = collection(['Data-snapshot','Index'],
           list_isin, EQTYIND_DEF.keys(),collect_eqind, False)
collect_eqind.head()
# Out:
#             NASA100-PH  NASA100-PL  NASA100-PO  NASCOMP-PH  NASCOMP-PL  \
# Date
# 2004-06-14     1471.19     1451.78     1470.62     1987.83     1963.48
# 2004-06-15     1487.83     1470.37     1470.37     2006.58     1982.41
# 2004-06-16     1483.60     1474.17     1478.72     2002.07     1990.57
# 2004-06-17     1473.95     1458.68     1473.94     1993.93     1976.25
# 2004-06-18     1481.36     1455.67     1457.88     2000.41     1973.91
#
#             NASCOMP-PO  S&PCOMP-PH  S&PCOMP-PL  S&PCOMP-PO  CBOEVIX-PH  \
# Date
# 2004-06-14     1987.75     1136.47     1122.16     1136.47       16.36
# 2004-06-15     1982.41     1137.36     1125.29     1126.55       15.35
# 2004-06-16     1997.10     1135.28     1130.55     1132.01       15.22
# 2004-06-17     1993.69     1133.56     1126.88     1133.56       15.58
# 2004-06-18     1977.77     1139.08     1129.82     1132.05       15.25
#
#             CBOEVIX-PL  CBOEVIX-PO
# Date
# 2004-06-14       15.54       15.54
# 2004-06-15       14.72       15.34
# 2004-06-16       14.48       14.83
# 2004-06-17       15.00       15.06
# 2004-06-18       14.51       14.74

# %%
# Process the Commodities
list_isin = ['GOLDBLN.txt',
             'OILBREN.txt',
             'OILWTXI.txt',
             'SILVUSL.txt']
variable_isin = COMMO_DEF.keys()

collect_como = collection(['Data-snapshot','Commodities'],
           list_isin, COMMO_DEF.keys())
collect_como = collection(['Data-snapshot','Commodities'],
           list_isin, COMMO_DEF.keys(),collect_como, False)
collect_como.head()
# Out:
#             GOLDBLN-P  GOLDBLN-PH  GOLDBLN-PL  GOLDBLN-PO  OILBREN-P  \
# Date
# 2004-01-02     415.50      416.65      414.60      416.05      29.67
# 2004-01-05     421.75      424.55      417.25      418.00      31.24
# 2004-01-06     422.25      431.00      421.15      424.25      31.14
# 2004-01-07     423.25      424.85      420.25      421.75      31.17
# 2004-01-08     422.25      424.85      417.25      419.75      31.19
#
#             OILBREN-PH  OILBREN-PL  OILWTXI-P  OILWTXI-PH  OILWTXI-PL  \
# Date
# 2004-01-02       29.67       29.67      32.29       32.29       32.29
# 2004-01-05       31.24       31.24      33.76       33.76       33.76
# 2004-01-06       31.14       31.14      33.62       33.62       33.62
# 2004-01-07       31.17       31.17      33.57       33.57       33.57
# 2004-01-08       31.19       31.19      34.08       34.08       34.08
#
#             SILVUSL-P
# Date
# 2004-01-02      5.985
# 2004-01-05      5.975
# 2004-01-06      6.280
# 2004-01-07      6.215
# 2004-01-08      6.200

# %%
# Process the Exchange Rates - FX
list_isin = ['JAPAYE$.txt',
             'USDOLSF.txt']
variable_isin = FX_DEF.keys()

collect_fx = collection(['Data-snapshot','FX'],
           list_isin, FX_DEF.keys())
collect_fx = collection(['Data-snapshot','FX'],
           list_isin, FX_DEF.keys(),collect_fx, False)
collect_fx.head()
# Out:
#             JAPAYE$-ER  USDOLSF-ER
# Date
# 2004-01-02     107.020         NaN
# 2004-01-05     106.135         NaN
# 2004-01-06     106.270         NaN
# 2004-01-07     106.160         NaN
# 2004-01-08     106.165         NaN

# %%
# Process the Options Continuous
list_isin = ['SPXC.SERIESC.txt',
             'SPXC.SERIESP.txt',
             'VIXC.SERIESC.txt',
             'VIXC.SERIESP.txt']
variable_isin = CONTINUOUS_OPTION_DEF.keys()

collect_cont_op = collection(['Data-snapshot','Option Index Continuous'],
           list_isin, CONTINUOUS_OPTION_DEF.keys())
collect_cont_op = collection(['Data-snapshot','Option Index Continuous'],
           list_isin, CONTINUOUS_OPTION_DEF.keys(),collect_cont_op, False)
collect_cont_op.head()
# Out:
#             SPXC.SERIESC-I3  SPXC.SERIESC-O1  SPXC.SERIESC-O3  \
# Date
# 2008-06-18           0.2380           0.2134           0.2157
# 2008-06-19           0.2378           0.2048           0.2058
# 2008-06-20           0.2418           0.2200           0.2150
# 2008-06-23           0.2421           0.2170           0.2163
# 2008-06-24           0.2316           0.2169           0.2199
#
#             SPXC.SERIESC-O6  SPXC.SERIESC-OI  SPXC.SERIESC-ON  \
# Date
# 2008-06-18           0.2177        4948198.0           0.2197
# 2008-06-19           0.2091        3060315.0           0.2162
# 2008-06-20           0.2187        3182287.0           0.2182
# 2008-06-23           0.2184        3222473.0           0.2186
# 2008-06-24           0.2174        3391221.0           0.2246
#
#             SPXC.SERIESC-OY  SPXC.SERIESC-VI  SPXC.SERIESC-VM  \
# Date
# 2008-06-18           0.2196          0.21301         359821.0
# 2008-06-19           0.2146          0.20559         396296.0
# 2008-06-20           0.2187          0.21879         256337.0
# 2008-06-23           0.2204          0.21153         187398.0
# 2008-06-24           0.1531          0.21630         248667.0
#
#             SPXC.SERIESP-I3  ...  VIXC.SERIESC-VI  VIXC.SERIESC-VM  \
# Date                         ...
# 2008-06-18           0.2385  ...              NaN              NaN
# 2008-06-19           0.2370  ...              NaN              NaN
# 2008-06-20           0.2372  ...              NaN              NaN
# 2008-06-23           0.2347  ...              NaN              NaN
# 2008-06-24           0.2369  ...              NaN              NaN
#
#             VIXC.SERIESP-O1  VIXC.SERIESP-O3  VIXC.SERIESP-O6  \
# Date
# 2008-06-18              NaN              NaN              NaN
# 2008-06-19              NaN              NaN              NaN
# 2008-06-20              NaN              NaN              NaN
# 2008-06-23              NaN              NaN              NaN
# 2008-06-24              NaN              NaN              NaN
#
#             VIXC.SERIESP-OI  VIXC.SERIESP-ON  VIXC.SERIESP-OY  \
# Date
# 2008-06-18              NaN              NaN              NaN
# 2008-06-19              NaN              NaN              NaN
# 2008-06-20              NaN              NaN              NaN
# 2008-06-23              NaN              NaN              NaN
# 2008-06-24              NaN              NaN              NaN
#
#             VIXC.SERIESP-VI  VIXC.SERIESP-VM
# Date
# 2008-06-18              NaN              NaN
# 2008-06-19              NaN              NaN
# 2008-06-20              NaN              NaN
# 2008-06-23              NaN              NaN
# 2008-06-24              NaN              NaN
#
# [5 rows x 34 columns]

# %%
# COMMENT: Economic data is split betweeen  Economic data and Economic Poll data
# Process Economic data
list_isin = ['USNAPMNO.txt', 'USPMNBC.Q.txt']
variable_isin = ECO_DEF.keys()
collect_eco = collection(['Data-snapshot','Economic'],
           list_isin, ECO_DEF.keys())
collect_eco = collection(['Data-snapshot','Economic'],
           list_isin, ECO_DEF.keys(),collect_eco, False)
collect_eco.head()
# Out:
#             USNAPMNO-ES  USPMNBC.Q-ES
# Date
# 2004-01-15         70.6           NaN
# 2004-02-15         66.5           NaN
# 2004-03-15         64.6           NaN
# 2004-04-15         67.1           NaN
# 2004-05-15         64.5           NaN

# %%
# Process Economic Poll 
list_isin = ['USBSINV.B.txt',
             'USCAPUS.R.txt',
             'USCAPUTLQ.txt',
             'USCNFBUSQ.txt',
             'USCNFCONQ.txt',
             'USCRDCONB.txt',
            'USCSHPM%E.txt', 'USPENONFO.txt', 'USUMINM1R.txt']
variable_isin = ECO_DEF.keys()
collect_poll = collection(['Data-snapshot','Economic Poll'],
           list_isin, ECO_DEF.keys())
collect_poll = collection(['Data-snapshot','Economic Poll'],
           list_isin, ECO_DEF.keys(),collect_poll, False)
collect_poll.head()
# Out:
#             USBSINV.B-ES  USCAPUS.R-ES  USCAPUTLQ-ES  USCNFBUSQ-ES  \
# Date
# 2004-01-30       1148846           NaN           NaN           NaN
# 2004-02-27       1158974           NaN           NaN           NaN
# 2004-03-31       1168294           NaN           NaN           NaN
# 2004-04-30       1176015           NaN           NaN           NaN
# 2004-05-31       1183315           NaN           NaN           NaN
#
#             USCNFCONQ-ES  USCRDCONB-ES  USCSHPM%E-ES  USPENONFO-ES  \
# Date
# 2004-01-30           NaN    2088.24304           NaN           NaN
# 2004-02-27           NaN    2095.34036           NaN           NaN
# 2004-03-31           NaN    2109.72032           NaN           NaN
# 2004-04-30           NaN    2112.71615           NaN           NaN
# 2004-05-31           NaN    2120.83915           NaN           NaN
#
#             USUMINM1R-ES
# Date
# 2004-01-30           NaN
# 2004-02-27           NaN
# 2004-03-31           NaN
# 2004-04-30           NaN
# 2004-05-31           NaN

# %%
# Process Interest Rates
list_isin = ['ECSWF1Y.txt']
variable_isin = IR_DEF.keys()

collect_ir = collection(['Data-snapshot','Interest Rates'],
           list_isin, IR_DEF.keys())
collect_ir = collection(['Data-snapshot','Interest Rates'],
           list_isin, IR_DEF.keys(),collect_ir, False)
collect_ir.head()
# Out:
#             ECSWF1Y-IR
# Date
# 2004-01-02      0.5781
# 2004-01-05      0.5938
# 2004-01-06      0.5469
# 2004-01-07      0.5781
# 2004-01-08      0.5156

# %% [raw]
# # NOT PROCESSED AT THE MOMENT
# # Process the Options
# list_isin = ['SPX04101255P.txt',
#              'SPX04101260P.txt']
# variable_isin = OP_DEF.keys()
#
# collect_op = collection(['Data-snapshot','Options Index'],
#            list_isin, OP_DEF.keys())
# variable_isin = OP_DEF.keys()
# #print collect
# collect_op = collection(['Data-snapshot','Options Index'],
#            list_isin, OP_DEF.keys(),collect_op, False)
# print collect_op.columns
# print min(collect_op.index), max(collect_op.index)

# %% [raw]
# # NOT PROCESSED AT THE MOMENT
# # Process Futures
# list_isin = ['CNI0307.txt',
#              'CNI0308.txt']
# variable_isin = FUT_DEF.keys()
#
# collect_fut = collection(['Data-snapshot','Futures'],
#            list_isin, FUT_DEF.keys())
# variable_isin = FUT_DEF.keys()
# #print collect
# collect_fut = collection(['Data-snapshot','Futures'],
#            list_isin, FUT_DEF.keys(),collect_fut, False)
# print collect_fut.columns
# print min(collect_fut.index), max(collect_fut.index)

# %% [markdown]
# ###  4.2 Static data
#
# This is just to form a pandas dataframe with all mnemonics collected and their description
#
# __Helper Functions__

# %%
# Process Static 
def process_s_df(path, filename, variable_isin):
    """
    Collect the variables for an isin. Save in a pandas dataframe. 
    path: folder name
    filename: file name where the isin information is located
    variable_isin: list of the variables for the isin to collect.
    """
    test = pd.read_csv(os.path.join(path,filename), sep=";",
                       header=0,infer_datetime_format=True,  encoding="utf-8")
    Col = list(test.columns)
    listcode = list(variable_isin)
    test.drop(set(test.columns).difference(set(listcode)),axis=1, inplace=True) 
    return test

def collection_s(path_in, list_isin, variable_isin, cumul_df=None, first_df=True):
    """
    Process the whole list of the isin for a type of financial instruments (equites, fx etc. )
    """
    source_path = os.path.join(os.getcwd(),*path_in)
    for position,filename in enumerate(list_isin):
        code_to_keep = variable_isin  # To avoid append "Date" at each computation
        if first_df:
            return process_s_df(source_path, filename, variable_isin)
        if position > 0:
            #print process_s_df(source_path, filename, variable_isin)
            cumul_df = pd.concat([cumul_df, process_s_df(source_path, filename, variable_isin)],axis=0)
    return cumul_df

# %% [markdown]
# __Collect__

# %%
# Process the equity Static information. 
list_isin = ['PA1436583006.txt',
             'US22160K1051.txt',
             'US4581401001.txt',
             'AN8068571086.txt']
variable_isin = EQUITY_STATIC.keys()

collect_s_eq = collection_s(['Data-snapshot','US Stocks Static'],
           list_isin, EQUITY_STATIC.keys())
collect_s_eq = collection_s(['Data-snapshot','US Stocks Static'],
           list_isin, EQUITY_STATIC.keys(),collect_s_eq, False)
# Rename ISIN into MENM for presentation purpose
collect_s_eq.columns = ['MNEM','NAME']
collect_s_eq['TYPE'] = 'Equity'
collect_s_eq.head()
# Out:
#            MNEM              NAME    TYPE
# 0  PA1436583006          CARNIVAL  Equity
# 0  US22160K1051  COSTCO WHOLESALE  Equity
# 0  US4581401001             INTEL  Equity
# 0  AN8068571086      SCHLUMBERGER  Equity

# %%
# Process the indicies - No information has been downloaded
# PUT THE DESCRIPTION FLAT and CONCATENATE
index_dict = {'CBOEVIX':'CHICAGO BOARD OF EXCHANGE VIX INDEX',
              'NASA100':'NASDAQ 100',
              'NASCOMP':'NASDAQ COMPOSITE',
              'S&PCOMP':'S&P 500 COMPOSITE'}

collect_s_index = pd.DataFrame.from_dict(index_dict,orient='index')
collect_s_index.index.name = 'MNEM'
collect_s_index.columns = ['NAME']
collect_s_index['TYPE'] = 'Index'
collect_s_index.reset_index(inplace=True)

# %%
# Process the Commodities
list_isin = ['GOLDBLN.txt',
             'OILBREN.txt',
             'OILWTXI.txt',
             'SILVUSL.txt']
variable_isin = COMMO_STATIC.keys()

collect_s_como = collection_s(['Data-snapshot','Commodities Static'],
           list_isin, COMMO_STATIC.keys())
collect_s_como = collection_s(['Data-snapshot','Commodities Static'],
           list_isin, COMMO_STATIC.keys(),collect_s_como, False)

collect_s_como['TYPE'] = 'Commodities'
collect_s_como.head()
# Out:
#       MNEM                                   NAME         TYPE
# 0  GOLDBLN         Gold Bullion LBM U$/Troy Ounce  Commodities
# 0  OILBREN  Crude Oil-Brent Cur. Month FOB U$/BBL  Commodities
# 0  OILWTXI    Crude Oil-WTI Near Month FOB U$/BBL  Commodities
# 0  SILVUSL          LBMA Silver Price USD/Troy Oz  Commodities

# %%
# Process the Exchange Rates
list_isin = ['JAPAYE$.txt',
             'USDOLSF.txt']
variable_isin = FX_STATIC.keys()

collect_s_fx = collection_s(['Data-snapshot','FX Static'],
           list_isin, FX_STATIC.keys())
collect_s_fx = collection_s(['Data-snapshot','FX Static'],
           list_isin, FX_STATIC.keys(),collect_s_fx, False)
collect_s_fx['TYPE'] = 'Currency'
collect_s_fx.head()
# Out:
#       MNEM                        NAME SICUR      TYPE
# 0  JAPAYE$  JAPANESE YEN TO US $ (WMR)    U$  Currency
# 0  USDOLSF           US $ TO CHF (WMR)    SF  Currency

# %%
# Process Economic
list_isin = ['USNAPMNO.txt','USBSINV.B.txt',
             'USCAPUS.R.txt',
             'USCAPUTLQ.txt',
             'USCNFBUSQ.txt',
             'USCNFCONQ.txt',
             'USCRDCONB.txt','USCSHPM%E.txt', 'USPENONFO.txt', 'USUMINM1R.txt']
variable_isin = ECO_STATIC.keys()
collect_s_eco = collection_s(['Data-snapshot','Economic Static'],
           list_isin, ECO_STATIC.keys())
collect_s_eco = collection_s(['Data-snapshot','Economic Static'],
           list_isin, ECO_STATIC.keys(),collect_s_eco, False)
collect_s_eco['TYPE'] = 'Economic'
collect_s_eco.head()
# Out:
#         MNEM                                               NAME      TYPE
# 0   USNAPMNO  US ISM MANUFACTURERS SURVEY: NEW ORDERS INDEX ...  Economic
# 0  USBSINV.B         US BUSINESS INVENTORIES (MFG & TRADE) CURA  Economic
# 0  USCAPUS.R  US REUTERS POLL: CAPACITY UTILIZATION (%MOM) -...  Economic
# 0  USCAPUTLQ   US CAPACITY UTILIZATION RATE - ALL INDUSTRY SADJ  Economic
# 0  USCNFBUSQ  US ISM PURCHASING MANAGERS INDEX (MFG SURVEY) ...  Economic

# %%
# Process Interest Rates
list_isin = ['ECSWF1Y.txt']
variable_isin = IR_STATIC.keys()
collect_s_ir = collection_s(['Data-snapshot','Interest Rates Static'],
           list_isin, IR_STATIC.keys())
collect_s_ir = collection_s(['Data-snapshot','Interest Rates Static'],
           list_isin, IR_STATIC.keys(),collect_s_ir, False)
collect_s_ir['TYPE'] = 'Interest Rate'
collect_s_ir.head()
# Out:
#       MNEM                            NAME           TYPE
# 0  ECSWF1Y  SWISS FRANC 1Y DEPOSIT (FT/TR)  Interest Rate

# %% [raw]
# # NOT PROCESSED AT THE MOMENT`
# # Process Futures
# list_isin = ['CNI0307.txt',
#              'CNI0308.txt']
# variable_isin = FUT_STATIC.keys()
#
# collect_s_fut = collection_s(['Data-snapshot','Futures Static'],
#            list_isin, FUT_STATIC.keys())
# variable_isin = FUT_STATIC.keys()
# #print collect_s_fut
# collect_s_fut = collection_s(['Data-snapshot','Futures Static'],
#            list_isin, FUT_STATIC.keys(),collect_s_fut, False)
#
# collect_s_fut['TYPE'] = 'Futures Contract'
# collect_s_fut

# %% [markdown]
# ##  5. Output results
#
# Save the pandas dataframes collected into 2 dataframes: time-series and static in "Data-processed" to build the

# %%
# Concatenate and output the data in folder 'Data-processed'
df_time_series = pd.concat([collect_eq, collect_corp, collect_eqind,
           collect_como,
           collect_fx,
#            collect_op,
           collect_cont_op,
#            collect_fut,
           collect_eco,
           collect_poll,
           collect_ir], axis=1,sort=True)
df_time_series.to_csv(os.path.join(os.getcwd(),'Data-processed', 'data_content.csv'), encoding='utf-8')
# Output risk file in folder 'Data-processed'
collect_risk.to_csv(os.path.join(os.getcwd(),'Data-processed', 'data_risk.csv'), encoding='utf-8')
df_time_series.head()
# Out:
#             PA1436583006-MVC  PA1436583006-P  PA1436583006-PH  \
# Date
# 2004-01-02          33610.74           39.82            40.25
# 2004-01-05          34121.62           40.43            40.61
# 2004-01-06          34297.64           40.75            40.80
# 2004-01-07          34380.14           40.83            41.00
# 2004-01-08          34754.78           41.24            41.30
#
#             PA1436583006-PL  PA1436583006-PO  US22160K1051-MVC  \
# Date
# 2004-01-02           39.750            39.91          16637.42
# 2004-01-05           40.185            40.28          16559.55
# 2004-01-06           40.300            40.43          16747.36
# 2004-01-07           40.550            40.70          16985.55
# 2004-01-08           40.850            40.87          17068.01
#
#             US22160K1051-P  US22160K1051-PH  US22160K1051-PL  US22160K1051-PO  \
# Date
# 2004-01-02           36.32           37.420            36.18            37.19
# 2004-01-05           36.15           36.610            35.86            36.44
# 2004-01-06           36.56           36.930            36.06            36.10
# 2004-01-07           37.08           37.175            36.52            36.58
# 2004-01-08           37.26           37.530            37.02            37.40
#
#             ...  USBSINV.B-ES  USCAPUS.R-ES  USCAPUTLQ-ES  USCNFBUSQ-ES  \
# Date        ...
# 2004-01-02  ...           NaN           NaN           NaN           NaN
# 2004-01-05  ...           NaN           NaN           NaN           NaN
# 2004-01-06  ...           NaN           NaN           NaN           NaN
# 2004-01-07  ...           NaN           NaN           NaN           NaN
# 2004-01-08  ...           NaN           NaN           NaN           NaN
#
#             USCNFCONQ-ES  USCRDCONB-ES  USCSHPM%E-ES  USPENONFO-ES  \
# Date
# 2004-01-02           NaN           NaN           NaN           NaN
# 2004-01-05           NaN           NaN           NaN           NaN
# 2004-01-06           NaN           NaN           NaN           NaN
# 2004-01-07           NaN           NaN           NaN           NaN
# 2004-01-08           NaN           NaN           NaN           NaN
#
#             USUMINM1R-ES  ECSWF1Y-IR
# Date
# 2004-01-02           NaN      0.5781
# 2004-01-05           NaN      0.5938
# 2004-01-06           NaN      0.5469
# 2004-01-07           NaN      0.5781
# 2004-01-08           NaN      0.5156
#
# [5 rows x 143 columns]

# %%
# Concatenate the description:
df_static = pd.concat([collect_s_eq,
           collect_s_index,
           collect_s_ir,
           collect_s_eco,
#           collect_s_fut[['MNEM','NAME','TYPE']],
           collect_s_como,
           collect_s_fx
          ],sort=True).set_index('MNEM')
df_static.to_csv(os.path.join(os.getcwd(),'Data-processed', 'data_list.csv'), encoding='utf-8')
df_static
# Out:
#                                                            NAME SICUR  \
# MNEM
# PA1436583006                                           CARNIVAL   NaN
# US22160K1051                                   COSTCO WHOLESALE   NaN
# US4581401001                                              INTEL   NaN
# AN8068571086                                       SCHLUMBERGER   NaN
# NASCOMP                                        NASDAQ COMPOSITE   NaN
# NASA100                                              NASDAQ 100   NaN
# S&PCOMP                                       S&P 500 COMPOSITE   NaN
# CBOEVIX                     CHICAGO BOARD OF EXCHANGE VIX INDEX   NaN
# ECSWF1Y                          SWISS FRANC 1Y DEPOSIT (FT/TR)   NaN
# USNAPMNO      US ISM MANUFACTURERS SURVEY: NEW ORDERS INDEX ...   NaN
# USBSINV.B            US BUSINESS INVENTORIES (MFG & TRADE) CURA   NaN
# USCAPUS.R     US REUTERS POLL: CAPACITY UTILIZATION (%MOM) -...   NaN
# USCAPUTLQ      US CAPACITY UTILIZATION RATE - ALL INDUSTRY SADJ   NaN
# USCNFBUSQ     US ISM PURCHASING MANAGERS INDEX (MFG SURVEY) ...   NaN
# USCNFCONQ                     US CONSUMER CONFIDENCE INDEX SADJ   NaN
# USCRDCONB                   US CONSUMER CREDIT OUTSTANDING CURA   NaN
# USCSHPM%E     US S&P/CASE-SHILLER HOME PRICE INDEX - 20-CITY...   NaN
# USPENONFO     US LABOUR MARKET: NONFARM EMPLOYMENT (ADP ESTI...   NaN
# USUMINM1R     US UMICH CSS: CONSUMER SENTIMENT: MEDIAN EXPEC...   NaN
# GOLDBLN                          Gold Bullion LBM U$/Troy Ounce   NaN
# OILBREN                   Crude Oil-Brent Cur. Month FOB U$/BBL   NaN
# OILWTXI                     Crude Oil-WTI Near Month FOB U$/BBL   NaN
# SILVUSL                           LBMA Silver Price USD/Troy Oz   NaN
# JAPAYE$                              JAPANESE YEN TO US $ (WMR)    U$
# USDOLSF                                       US $ TO CHF (WMR)    SF
#
#                        TYPE
# MNEM
# PA1436583006         Equity
# US22160K1051         Equity
# US4581401001         Equity
# AN8068571086         Equity
# NASCOMP               Index
# NASA100               Index
# S&PCOMP               Index
# CBOEVIX               Index
# ECSWF1Y       Interest Rate
# USNAPMNO           Economic
# USBSINV.B          Economic
# USCAPUS.R          Economic
# USCAPUTLQ          Economic
# USCNFBUSQ          Economic
# USCNFCONQ          Economic
# USCRDCONB          Economic
# USCSHPM%E          Economic
# USPENONFO          Economic
# USUMINM1R          Economic
# GOLDBLN         Commodities
# OILBREN         Commodities
# OILWTXI         Commodities
# SILVUSL         Commodities
# JAPAYE$            Currency
# USDOLSF            Currency
