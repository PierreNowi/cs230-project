# %% [markdown]
# # Pre-process data folder
#
# Collect the information in "/Data" (or "/Data-snapshot" for the illutration) to collect the Data for the evaluation.
# Collect the market information to describe the environment.
#
# Do
# * Put a proper interest rate in the test dataset
# * Do all the collection of the Data for the position.
# * Do all the collection for the prediction function - index etc.
# * Do all the collection for the informatoin coefficient generation

# %% [markdown]
# 1. load the libraries

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# 2. Constants
#
# Define Date as "YYYY-MM-DD"

# %%
DATE_MIN = "01/01/2005"# Date minimum at which the evaluation starts. (Should contain the train/dev/text sets)
DATE_MAX = "2015-01-01" # Date maximum at which the evaluation end.

# %%
equities = "Equities Datastream Data Identifier_Cleaned.xls"
equities_indices = "Equities Indices Data Identifier_Cleaned.xls"
fx = "Exchange Rate Data Identifier_Cleaned.xls"
commodities = "Commodities Data Identifier_Cleaned.xls"
economic = "Economics Data Identifier_Cleaned.xls"
futures = "Futures Data Identifier_Cleaned.xls"
interest_rate = "Interest Rates Data Identifier_Cleaned.xls"
options = "Options Data Identifier_Cleaned.xls"

# %%
def print_codes(label):
    name= pd.read_excel(os.path.join(os.getcwd(),"Data","Description","Data Type",label))
    name = name[['Name','Symbol','Type']]
    return name[name['Type']== 'Time Series'] , name[name['Type']== 'Static']

# %%
timeseries, static = print_codes(options)

# %%
timeseries.loc[:200, ['Name','Symbol']].set_index('Symbol').to_dict()
# Out:
# {'Name': {u'DZ': u'Delta',
#   u'FV': u'Fair Value',
#   u'GM': u'Gamma',
#   u'I2': u'Implied Volatility - 2 Year Constant Maturity (Cont Series)',
#   u'I3': u'Implied Volatility - 3 Year Constant Maturity (Cont Series)',
#   u'I4': u'Implied Volatility - 4 Year Constant Maturity (Cont Series)',
#   u'I5': u'Implied Volatility - 5 Year Constant Maturity (Cont Series)',
#   u'MP': u'Price - Market',
#   u'O1': u'Implied Volatility - 1 Month Constant Maturity (Cont Series)',
#   u'O2': u'Implied Volatility - 2 Month Constant Maturity (Cont Series)',
#   u'O3': u'Implied Volatility - 3 Month Constant Maturity (Cont Series)',
#   u'O6': u'Implied Volatility - 6 Month Constant Maturity (Cont Series)',
#   u'OC': u'Implied Volatility - Spot - Week Constant Maturity (Cont Series)',
#   u'OD': u'Implied Volatility - 1 Week Constant Maturity (Cont Series)',
#   u'OI': u'Open Interest',
#   u'OM': u'At The Money Option Price (Cont Series)',
#   u'ON': u'Implied Volatility - 9 Month Constant Maturity (Cont Series)',
#   u'OS': u'At The Money Strike Price (Cont Series)',
#   u'OU': u'Underlying Price (Cont Series)',
#   u'OUP': u'Underlying Series Price (Single Series)',
#   u'OV': u'Implied Volatility - At The Money Nearest Strike (Cont Series)',
#   u'OY': u'Implied Volatility - 1 Year Constant Maturity (Cont Series)',
#   u'P': u'Price (Adjusted - Default)',
#   u'PA': u'Price - Ask',
#   u'PB': u'Price - Bid',
#   u'PH': u'Price - Intraday High',
#   u'PL': u'Price - Intraday Low',
#   u'PO': u'Price - Opening',
#   u'TA': u'Theta (Single Series)',
#   u'VG': u'Vega, Kappa',
#   u'VI': u'Implied Volatility - At The Money Interpolated (Cont Series)',
#   u'VL': u'Implied Volatility (Single Series)',
#   u'VM': u'Volume of Contracts Traded',
#   u'VX': u'Implied Volatility - Trade Weighted (Cont Series)'}}

# %%
static.loc[0:100, ['Name','Symbol']].set_index('Symbol').to_dict()
# Out:
# {'Name': {u'MNEM': u'Mnemonic',
#   u'NAME': u'Name',
#   u'OEX': u'Exchange',
#   u'OEXT': u'Expiry Style',
#   u'OLOT': u'Lot Size (Single Series)',
#   u'OPMOD': u'Option Model Calculation',
#   u'OPTCODE': u'Exchange Ticker Symbol',
#   u'OPTYPE': u'Option Underlying Instrument Type',
#   u'OTYP': u'Option Type (Single Series)',
#   u'OUI': u'Underlying Series Mnemonic',
#   u'OUN': u'Underlying Series Name (Single Series)',
#   u'OXCP': u'Exercise Price (Single Series)',
#   u'OXPD': u'Expiry Date (Single Series)',
#   u'PCUR': u'Price - Currency',
#   u'TCYCLE': u'Trading Cycle',
#   u'TIME': u'Time - Latest Value',
#   u'TYPE': u'Type Of Instrument'}}

# %%
CORPORATE_DEF = {
    "WC08101":"QUICK RATIO",                                            
"WC08106":"CURRENT RATIO",  
    "WC08316":"OPERATING PROFIT MARGIN  ",
    "WC03051":"SHORT TERM DEBT & CURRENT PORTION OF LONG TERM DEBT",
    "WC08311":"CASH FLOW/SALES",
    "WC08316":"OPERATING PROFIT MARGIN",
    "WC08221":"TOTAL DEBT % TOTAL CAPITAL & SHORT TERM DEBT",       
"WC08231":"TOTAL DEBT % COMMON EQUITY",
    "WC18191":"EARNINGS BEFORE INTEREST AND TAXES (EBIT)"  
    }

# %% [raw]
# WC01001  	NET SALES OR REVENUES
# WC01001  	NET SALES OR REVENUES
# WC01002  	PREMIUMS EARNED
# WC01016  	INTEREST INCOME - TOTAL
# WC01051  	COST OF GOODS SOLD (EXCL DEPRECIATION)
# WC01075  	INTEREST EXPENSE - TOTAL
# WC01076  	NET INTEREST INCOME
# WC01084  	SALARIES AND BENEFITS EXPENSES
# WC01100  	GROSS INCOME
# WC01101  	SELLING, GENERAL & ADMINISTRATIVE EXPENSES
# WC01149  	AMORTIZATION OF INTANGIBLES
# WC01150  	AMORTIZATION OF DEFERRED CHARGES
# WC01151  	DEPRECIATION, DEPLETION AND AMORTIZATION
# WC01201  	RESEARCH & DEVELOPMENT
# WC01250  	OPERATING INCOME
# WC01251  	INTEREST EXPENSE ON DEBT
# WC01253  	EXTRAORDINARY CREDIT - PRETAX
# WC01254  	EXTRAORDINARY CHARGE - PRETAX
# WC01255  	INTEREST CAPITALIZED
# WC01266  	NON-OPERATING INTEREST INCOME
# WC01271  	PROVISION FOR LOAN LOSSES
# WC01401  	PRETAX INCOME
# WC01451  	INCOME TAXES
# WC01501  	MINORITY INTEREST
# WC01551  	NET INCOME BEFORE EXTRA ITEMS/PREFERRED DIVIDENDS
# WC01601  	EXTRA ITEMS & GAIN/LOSS SALE OF ASSETS
# WC01701  	PREFERRED DIVIDEND REQUIREMENTS
# WC01705  	NET INCOME USED TO CALCULATE DILUTED EARNINGS PER SHARE
# WC01706  	NET INCOME USED TO CALCULATE BASIC EARNINGS PER SHARE
# WC01751  	NET INCOME AVAILABLE TO COMMON
# WC02001  	CASH & SHORT TERM INVESTMENTS
# WC02003  	CASH
# WC02004  	CASH & DUE FROM BANKS
# WC02051  	RECEIVABLES(NET)
# WC02101  	INVENTORIES - TOTAL
# WC02201  	CURRENT ASSETS - TOTAL
# WC02255  	INVESTMENTS - TOTAL
# WC02276  	LOANS - NET
# WC02501  	PROPERTY, PLANT AND EQUIPMENT - NET
# WC02649  	TOTAL INTANGIBLE OTHER ASSETS - NET
# WC02999  	TOTAL ASSETS
# WC03019  	DEPOSITS - TOTAL
# WC03030  	INSURANCE RESERVES - TOTAL
# WC03040  	ACCOUNTS PAYABLE
# WC03051  	SHORT TERM DEBT & CURRENT PORTION OF LONG TERM DEBT
# WC03101  	CURRENT LIABILITIES - TOTAL
# WC03151  	WORKING CAPITAL
# WC03251  	LONG TERM DEBT
# WC03255  	TOTAL DEBT
# WC03263  	DEFERRED TAXES
# WC03426  	MINORITY INTEREST
# WC03451  	PREFERRED STOCK
# WC03480  	COMMON STOCK
# WC03501  	COMMON EQUITY
# WC03998  	TOTAL CAPITAL
# WC04050  	AMORTIZATION OF INTANGIBLE ASSETS
# WC04201  	FUNDS FROM OPERATIONS
# WC04251  	NET PROCEEDS FROM SALE/ISSUE OF COMMON & PREFERRED
# WC04551  	CASH DIVIDENDS PAID - TOTAL
# WC04601  	CAPITAL EXPENDITURES (ADDITIONS TO FIXED ASSETS)
# WC04851  	INCREASE/DECREASE IN CASH AND SHORT TERM INVESTMENTS
# WC04860  	NET CASH FLOW - OPERATING ACTIVITIES
# WC04870  	NET CASH FLOW - INVESTING
# WC04890  	NET CASH FLOW - FINANCING
# WC05350  	DATE OF FISCAL YEAR END
# WC05376  	COMMON DIVIDENDS (CASH)
# WC06026  	NATION
# WC07011  	EMPLOYEES
# WC08101  	QUICK RATIO
# WC08106  	CURRENT RATIO
# WC08126  	INVENTORIES - DAYS HELD
# WC08131  	ACCOUNTS RECEIVABLES DAYS
# WC08221  	TOTAL DEBT % TOTAL CAPITAL & SHORT TERM DEBT
# WC08231  	TOTAL DEBT % COMMON EQUITY
# WC08301  	RETURN ON EQUITY - TOTAL (%)
# WC08311  	CASH FLOW/SALES
# WC08316  	OPERATING PROFIT MARGIN
# WC08321  	PRETAX MARGIN
# WC08366  	NET MARGIN
# WC08376  	RETURN ON INVESTED CAPITAL
# WC18191  	EARNINGS BEFORE INTEREST AND TAXES (EBIT)
# WC18192  	DIVIDENDS PROVIDED FOR OR PAID - COMMON
# WC18198  	EBIT & DEPRECIATION

# %%
CONTINUOUS_OPTION_DEF = {
    "MP":"Price - Market",
    "VI":"Implied Volatility - At The Money Interpolated (Cont Series)",
    "OI":"Open Interest",
    "VM":"Volume of Contracts Traded",
    "OD":"Implied Volatility - 1 Week Constant Maturity (Cont Series)",
    "O1":"Implied Volatility - 1 Month Constant Maturity (Cont Series)",
    "O3": "Implied Volatility - 3 Month Constant Maturity (Cont Series)",
    "O6": "Implied Volatility - 6 Month Constant Maturity (Cont Series)",
    "ON":"Implied Volatility - 9 Month Constant Maturity (Cont Series)",
    "OY":"Implied Volatility - 1 Year Constant Maturity (Cont Series)",
    "I3":"Implied Volatility - 3 Year Constant Maturity (Cont Series)",
}

CONTINUOUS_OPTION_STATIC = {
    "MNEM": "Mnemonic",
"NAME":"Name",
    "OPTYPE":"Option Underlying Instrument Type"
}

# %% [raw]
# Implied Volatility (Single Series)	VL	Time Series
# Price - Market	MP	Time Series
# Implied Volatility - At The Money Interpolated (Cont Series)	VI	Time Series
# Open Interest	OI	Time Series
# Volume of Contracts Traded	VM	Time Series
# Delta	DZ	Time Series
# Underlying Price (Cont Series)	OU	Time Series
# Exercise Price (Single Series)	OXCP	Static
# Expiry Date (Single Series)	OXPD	Static
# Price - Intraday High	PH	Time Series
# Price - Intraday Low	PL	Time Series
# Price - Opening	PO	Time Series
# Underlying Series Price (Single Series)	OUP	Time Series
# At The Money Option Price (Cont Series)	OM	Time Series
# At The Money Strike Price (Cont Series)	OS	Time Series
# Exchange	OEX	Static
# Exchange Ticker Symbol	OPTCODE	Static
# Expiry Style	OEXT	Static
# Fair Value	FV	Time Series
# Gamma	GM	Time Series
# Implied Volatility - 1 Month Constant Maturity (Cont Series)	O1	Time Series
# Implied Volatility - 1 Week Constant Maturity (Cont Series)	OD	Time Series
# Implied Volatility - 1 Year Constant Maturity (Cont Series)	OY	Time Series
# Implied Volatility - 2 Month Constant Maturity (Cont Series)	O2	Time Series
# Implied Volatility - 2 Year Constant Maturity (Cont Series)	I2	Time Series
# Implied Volatility - 3 Month Constant Maturity (Cont Series)	O3	Time Series
# Implied Volatility - 3 Year Constant Maturity (Cont Series)	I3	Time Series
# Implied Volatility - 4 Year Constant Maturity (Cont Series)	I4	Time Series
# Implied Volatility - 5 Year Constant Maturity (Cont Series)	I5	Time Series
# Implied Volatility - 6 Month Constant Maturity (Cont Series)	O6	Time Series
# Implied Volatility - 9 Month Constant Maturity (Cont Series)	ON	Time Series
# Implied Volatility - At The Money Nearest Strike (Cont Series)	OV	Time Series
# Implied Volatility - Spot - Week Constant Maturity (Cont Series)	OC	Time Series
# Implied Volatility - Trade Weighted (Cont Series)	VX	Time Series
# Lot Size (Single Series)	OLOT	Static
# Mnemonic	MNEM	Static
# Name	NAME	Static
# Option Model Calculation	OPMOD	Static
# Option Type (Single Series)	OTYP	Static
# Option Underlying Instrument Type	OPTYPE	Static
# Price (Adjusted - Default)	P	Time Series
# Price - Ask	PA	Time Series
# Price - Bid	PB	Time Series
# Price - Currency	PCUR	Static
# Theta (Single Series)	TA	Time Series
# Time - Latest Value	TIME	Static
# Trading Cycle	TCYCLE	Static
# Type Of Instrument	TYPE	Static
# Underlying Series Mnemonic	OUI	Static
# Underlying Series Name (Single Series)	OUN	Static
# Vega, Kappa	VG	Time Series

# %%
# Define constants for Options to collect
OP_DEF = {
    u'P': u'Price (Adjusted - Default)',
  u'PH': u'Price - Intraday High',
  u'PL': u'Price - Intraday Low',
  u'PO': u'Price - Opening',
    u'OU': u'Underlying Price (Cont Series)',
    u'OI': u'Open Interest',
    u'O1': u'Implied Volatility - 1 Month Constant Maturity (Cont Series)',
  u'O2': u'Implied Volatility - 2 Month Constant Maturity (Cont Series)',
  u'O3': u'Implied Volatility - 3 Month Constant Maturity (Cont Series)',
  u'O6': u'Implied Volatility - 6 Month Constant Maturity (Cont Series)',
     u'VI': u'Implied Volatility - At The Money Interpolated (Cont Series)',
    u'VM': u'Volume of Contracts Traded'
}
OP_STATIC = {u'MNEM': u'Mnemonic',
             u'NAME': u'Name',
             u'OEXT': u'Expiry Style',
             u'OXCP': u'Exercise Price (Single Series)',
  u'OXPD': u'Expiry Date (Single Series)',
  u'PCUR': u'Price - Currency',
             u'OTYP': u'Option Type (Single Series)',
  u'OUI': u'Underlying Series Mnemonic',
             u'TYPE': u'Type Of Instrument'}

# %%
# Define constants for Interest Rate to collect
IR_DEF = {
    u'IR': u'Interest Rate'}
IR_STATIC = {u'MNEM': u'Mnemonic',u'NAME': u'Name',u'TYPE': u'Type Of Instrument'}

# %%
# Define constants for Futures to collect
FUT_DEF = {
    u'PS': u'Settlement Price',
    u'PH': u'Price - Intraday High',
  u'PL': u'Price - Intraday Low',
  u'PO': u'Price - Opening',
    u'VM': u'Volume of Contracts Traded'}
FUT_STATIC = {
    u'MNEM': u'Mnemonic',
  u'NAME': u'Name',
    u'FUTBDATE': u'Start Date (Futures)',
    u'FUI': u'Underlying Instrument',
    u'STDT': u'Settlement Date'}

# %%
# Define constants for Economic indicators to collect
ECO_DEF = {
    u'ES': u'Economic Series - Weekly'}
ECO_STATIC = {
    u'MNEM': u'Mnemonic',
  u'NAME': u'Name',
    u'TYPE': u'Type Of Instrument'
}

# %%
# Define constants for Commodities to collect
COMMO_DEF = {
    u'PO': u'Price - Opening',
    u'PH': u'Price - Intraday High',
u'PL': u'Price - Intraday Low',
u'P': u'Price (Adjusted - Default)'}
COMMO_STATIC = {
    u'MNEM': u'Mnemonic',
  u'NAME': u'Name'
}

# %%
# Define constants for equities indices to collect
EQTYIND_DEF = {
    u'P': u'Price (Adjusted - Default)',
    u'PH': u'Price - Intraday High',
  u'PL': u'Price - Intraday Low',
  u'PO': u'Price - Opening'}
EQTYIND_STATIC = {
    u'ISIN': u'Code - Isin',
    u'NAME': u'Name',
}

# %%
# Define constants for equities to collect
EQUITY_DEF = {
    u'P': u'Price (Adjusted - Default)',
    u'PH': u'Price - Intraday High',
  u'PL': u'Price - Intraday Low',
  u'PO': u'Price - Opening'}
EQUITY_STATIC = {
    u'ISIN': u'Code - Isin',
    u'NAME': u'Name',
}

# %%
# Define constants for Currencies to collect
FX_DEF = {u'ER': u'Exchange Rate - Middle'}
FX_STATIC = {u'MNEM': u'Mnemonic',
             u'NAME': u'Name',
             u'SICUR': u'Currency'}

# %%
listcode = EQUITY_DEF.keys()
listcode
# first = True 
# source_path = os.path.join(os.getcwd(),*['Data-snapshot','US Stocks'])
# target_path = os.path.join(os.getcwd(),*['Data-processed'])
# print os.listdir(source_path)
# for filename in os.listdir(source_path):
#     if filename.endswith(".txt"):
#         test = pd.read_csv(os.path.join(source_path,filename), sep=";",
#             header=0,parse_dates=[0],infer_datetime_format=True,  encoding="utf-8")
#         Col = list(test.columns)
#         isin = Col[0]
#         Col[0] = 'Date'
#         test.columns = Col
#         #print (set(test.columns))
#         listcode.append('Date')
#         test.drop(set(test.columns).difference(set(listcode)),axis=1, inplace=True) 
#         test.columns = [isin + "-" + i for i in (test.columns)]
#         test.set_index(isin +"-" +'Date', inplace=True)
#         test.index.name = 'Date'
#         #print test.loc[(test.index > DATE_MIN) & (test.index < DATE_MAX)].dropna()  # Dropna for non Quoted day ie xmas
#         # Affect to the value
#         if first:
#             print "ok"
#             #test.loc[(test.index > DATE_MIN) & (test.index < DATE_MAX)].dropna()
# Out:
# [u'P', u'PH', u'PO', u'PL']

# %%
# Collect the list of a type of Data and append it to a dataframe. 
def process_df(path, filename, variable_isin):
#     print "Process df filename", filename
#     print "Process df path", path
#     print "Process df variable isin", variable_isin
    test = pd.read_csv(os.path.join(path,filename), sep=";",
                       header=0,parse_dates=[0],infer_datetime_format=True,  encoding="utf-8")
    Col = list(test.columns)
    isin = Col[0]
    Col[0] = 'Date'
    test.columns = Col
    listcode = list(variable_isin)
    listcode.append('Date')
#     print "Process df liste code with Date added", listcode
    test.drop(set(test.columns).difference(set(listcode)),axis=1, inplace=True) 
    test.columns = [isin + "-" + i for i in (test.columns)]
    test.set_index(isin + "-" +'Date', inplace=True)
    test.index.name = 'Date'
    #print "Process df test index with Date and cleaned", test.index
    return test.loc[(test.index > DATE_MIN) & (test.index < DATE_MAX)].dropna()

def collection(path_in, path_out, list_isin, variable_isin, cumul_df=None, first_df=True):
    source_path = os.path.join(os.getcwd(),*path_in)
    target_path = os.path.join(os.getcwd(),*path_out)
    for position,filename in enumerate(list_isin):
#         print "Collection Source path", source_path
#         print "Collection filename", filename
#         print "Collection variable isin",variable_isin
        code_to_keep = variable_isin  # To avoid append "Date" at each computation
        if first_df:
            return process_df(source_path, filename, variable_isin)
        if position > 0:
            #print process_df(source_path, filename,variable_isin, listcode).head()
            cumul_df = cumul_df.join(process_df(source_path, filename, variable_isin))
    return cumul_df

# %%
# Process the equity
list_isin = ['PA1436583006.txt', 'US4581401001.txt', 'US22160K1051.txt', 'US92343E1029.txt', 'AN8068571086.txt']
variable_isin = EQUITY_DEF.keys()

collect_eq = collection(['Data-snapshot','US Stocks'],
           ['Data-processed'],
           list_isin, EQUITY_DEF.keys())
variable_isin = EQUITY_DEF.keys()
#print collect
collect_eq = collection(['Data-snapshot','US Stocks'],
           ['Data-processed'],
           list_isin, EQUITY_DEF.keys(),collect_eq, False)
print collect_eq.columns
print min(collect_eq.index), max(collect_eq.index)
print collect_eq.index.dtype
# Out:
# Index([u'PA1436583006-P', u'PA1436583006-PH', u'PA1436583006-PL',
#        u'PA1436583006-PO', u'US4581401001-P', u'US4581401001-PH',
#        u'US4581401001-PL', u'US4581401001-PO', u'US22160K1051-P',
#        u'US22160K1051-PH', u'US22160K1051-PL', u'US22160K1051-PO',
#        u'US92343E1029-P', u'US92343E1029-PH', u'US92343E1029-PL',
#        u'US92343E1029-PO', u'AN8068571086-P', u'AN8068571086-PH',
#        u'AN8068571086-PL', u'AN8068571086-PO'],
#       dtype='object')
# 2005-01-03 00:00:00 2014-12-31 00:00:00
# datetime64[ns]

# %%
# Process the equity of corporate finance
list_isin = ['PA1436583006.txt', 'US4581401001.txt', 'US22160K1051.txt', 'US92343E1029.txt', 'AN8068571086.txt']
variable_isin = CORPORATE_DEF.keys()

collect_corp = collection(['Data-snapshot','US Stocks'],
           ['Data-processed'],
           list_isin, CORPORATE_DEF.keys())
variable_isin = CORPORATE_DEF.keys()
#print collect_corp
collect_corp = collection(['Data-snapshot','US Stocks'],
           ['Data-processed'],
           list_isin, CORPORATE_DEF.keys(),collect_corp, False)
print collect_corp.columns
print min(collect_corp.index), max(collect_corp.index)
print collect_corp.index.dtype
collect_corp.head()
# Out:
# Index([u'PA1436583006-WC03051', u'PA1436583006-WC08101',
#        u'PA1436583006-WC08106', u'PA1436583006-WC08221',
#        u'PA1436583006-WC08231', u'PA1436583006-WC08311',
#        u'PA1436583006-WC08316', u'PA1436583006-WC18191',
#        u'US4581401001-WC03051', u'US4581401001-WC08101',
#        u'US4581401001-WC08106', u'US4581401001-WC08221',
#        u'US4581401001-WC08231', u'US4581401001-WC08311',
#        u'US4581401001-WC08316', u'US4581401001-WC18191',
#        u'US22160K1051-WC03051', u'US22160K1051-WC08101',
#        u'US22160K1051-WC08106', u'US22160K1051-WC08221',
#        u'US22160K1051-WC08231', u'US22160K1051-WC08311',
#        u'US22160K1051-WC08316', u'US22160K1051-WC18191',
#        u'US92343E1029-WC03051', u'US92343E1029-WC08101',
#        u'US92343E1029-WC08106', u'US92343E1029-WC08221',
#        u'US92343E1029-WC08231', u'US92343E1029-WC08311',
#        u'US92343E1029-WC08316', u'US92343E1029-WC18191',
#        u'AN8068571086-WC03051', u'AN8068571086-WC08101',
#        u'AN8068571086-WC08106', u'AN8068571086-WC08221',
#        u'AN8068571086-WC08231', u'AN8068571086-WC08311',
#        u'AN8068571086-WC08316', u'AN8068571086-WC18191'],
#       dtype='object')
# 2005-01-03 00:00:00 2014-11-24 00:00:00
# datetime64[ns]
#             PA1436583006-WC03051  PA1436583006-WC08101  PA1436583006-WC08106  \
# Date
# 2005-01-03             1625000.0                  0.31                  0.43
# 2005-01-10             1625000.0                  0.31                  0.43
# 2005-01-17             1625000.0                  0.31                  0.43
# 2005-01-24             1625000.0                  0.31                  0.43
# 2005-01-31             1625000.0                  0.31                  0.43
#
#             PA1436583006-WC08221  PA1436583006-WC08231  PA1436583006-WC08311  \
# Date
# 2005-01-03                 30.23                 43.32                 29.01
# 2005-01-10                 30.23                 43.32                 29.01
# 2005-01-17                 30.23                 43.32                 29.01
# 2005-01-24                 30.23                 43.32                 29.01
# 2005-01-31                 30.23                 43.32                 29.01
#
#             PA1436583006-WC08316  PA1436583006-WC18191  US4581401001-WC03051  \
# Date
# 2005-01-03                  23.8             2660000.0              313000.0
# 2005-01-10                  23.8             2660000.0              313000.0
# 2005-01-17                  23.8             2660000.0              313000.0
# 2005-01-24                  23.8             2660000.0              313000.0
# 2005-01-31                  23.8             2660000.0              313000.0
#
#             US4581401001-WC08101  ...  US92343E1029-WC08316  \
# Date                              ...
# 2005-01-03                  1.81  ...                   NaN
# 2005-01-10                  1.81  ...                   NaN
# 2005-01-17                  1.81  ...                   NaN
# 2005-01-24                  1.81  ...                   NaN
# 2005-01-31                  1.81  ...                   NaN
#
#             US92343E1029-WC18191  AN8068571086-WC03051  AN8068571086-WC08101  \
# Date
# 2005-01-03                   NaN              796000.0                  1.25
# 2005-01-10                   NaN              796000.0                  1.25
# 2005-01-17                   NaN              796000.0                  1.25
# 2005-01-24                   NaN              796000.0                  1.25
# 2005-01-31                   NaN              796000.0                  1.25
#
#             AN8068571086-WC08106  AN8068571086-WC08221  AN8068571086-WC08231  \
# Date
# 2005-01-03                  1.55                 35.14                 57.78
# 2005-01-10                  1.55                 35.14                 57.78
# 2005-01-17                  1.55                 35.14                 57.78
# 2005-01-24                  1.55                 35.14                 57.78
# 2005-01-31                  1.55                 35.14                 57.78
#
#             AN8068571086-WC08311  AN8068571086-WC08316  AN8068571086-WC18191
# Date
# 2005-01-03                 23.66                 19.38             3060000.0
# 2005-01-10                 23.66                 19.38             3060000.0
# 2005-01-17                 23.66                 19.38             3060000.0
# 2005-01-24                 23.66                 19.38             3060000.0
# 2005-01-31                 23.66                 19.38             3060000.0
#
# [5 rows x 40 columns]

# %%
# Process the indicies
list_isin = ['NASA100.txt', 'NASCOMP.txt', 'S&PCOMP.txt','CBOEVIX.txt']
variable_isin = EQTYIND_DEF.keys()

collect_eqind = collection(['Data-snapshot','Index'],
           ['Data-processed'],
           list_isin, EQTYIND_DEF.keys())
variable_isin = EQTYIND_DEF.keys()
#print collect
collect_eqind = collection(['Data-snapshot','Index'],
           ['Data-processed'],
           list_isin, EQTYIND_DEF.keys(),collect_eqind, False)
print collect_eqind.columns
print min(collect_eqind.index), max(collect_eqind.index)
# Out:
# Index([u'NASA100-PH', u'NASA100-PL', u'NASA100-PO', u'NASCOMP-PH',
#        u'NASCOMP-PL', u'NASCOMP-PO', u'S&PCOMP-PH', u'S&PCOMP-PL',
#        u'S&PCOMP-PO', u'CBOEVIX-PH', u'CBOEVIX-PL', u'CBOEVIX-PO'],
#       dtype='object')
# 2005-01-03 00:00:00 2014-12-31 00:00:00

# %%
# Process the Commodities
list_isin = ['GOLDBLN.txt', 'OILBREN.txt', 'OILWTXI.txt', 'SILVUSL.txt']
variable_isin = COMMO_DEF.keys()

collect_como = collection(['Data-snapshot','Commodities'],
           ['Data-processed'],
           list_isin, COMMO_DEF.keys())
variable_isin = COMMO_DEF.keys()
#print collect
collect_como = collection(['Data-snapshot','Commodities'],
           ['Data-processed'],
           list_isin, COMMO_DEF.keys(),collect_como, False)
print collect_como.columns
print min(collect_como.index), max(collect_como.index)
# Out:
# Index([u'GOLDBLN-P', u'GOLDBLN-PH', u'GOLDBLN-PL', u'GOLDBLN-PO', u'OILBREN-P',
#        u'OILBREN-PH', u'OILBREN-PL', u'OILWTXI-P', u'OILWTXI-PH',
#        u'OILWTXI-PL', u'SILVUSL-P'],
#       dtype='object')
# 2005-01-04 00:00:00 2014-12-31 00:00:00

# %%
# Process the Exchange Rates
list_isin = ['JAPAYE$.txt', 'USDOLSF.txt']
variable_isin = FX_DEF.keys()

collect_fx = collection(['Data-snapshot','FX'],
           ['Data-processed'],
           list_isin, FX_DEF.keys())
variable_isin = FX_DEF.keys()
#print collect
collect_fx = collection(['Data-snapshot','FX'],
           ['Data-processed'],
           list_isin, FX_DEF.keys(),collect_fx, False)
print collect_fx.columns
print min(collect_fx.index), max(collect_fx.index)
# Out:
# Index([u'JAPAYE$-ER', u'USDOLSF-ER'], dtype='object')
# 2005-01-03 00:00:00 2014-12-31 00:00:00

# %%
# Process the Options
list_isin = ['SPX04101255P.txt', 'SPX04101260P.txt']
variable_isin = OP_DEF.keys()

collect_op = collection(['Data-snapshot','Options Index'],
           ['Data-processed'],
           list_isin, OP_DEF.keys())
variable_isin = OP_DEF.keys()
#print collect
collect_op = collection(['Data-snapshot','Options Index'],
           ['Data-processed'],
           list_isin, OP_DEF.keys(),collect_op, False)
print collect_op.columns
print min(collect_op.index), max(collect_op.index)
# Out:
# Index([u'SPX04101255P-OI', u'SPX04101255P-PH', u'SPX04101255P-PL',
#        u'SPX04101255P-PO', u'SPX04101255P-VM', u'SPX04101260P-OI',
#        u'SPX04101260P-PH', u'SPX04101260P-PL', u'SPX04101260P-PO',
#        u'SPX04101260P-VM'],
#       dtype='object')
# 2010-04-06 00:00:00 2010-04-09 00:00:00

# %%
# Process the Options Continuous
list_isin = ['SPXC.SERIESC.txt', 'SPXC.SERIESP.txt', 'VIXC.SERIESC.txt', 'VIXC.SERIESP.txt']
variable_isin = CONTINUOUS_OPTION_DEF.keys()

collect_cont_op = collection(['Data-snapshot','Option Index Continuous'],
           ['Data-processed'],
           list_isin, CONTINUOUS_OPTION_DEF.keys())
variable_isin = CONTINUOUS_OPTION_DEF.keys()
#print collect_cont_op
collect_cont_op = collection(['Data-snapshot','Option Index Continuous'],
           ['Data-processed'],
           list_isin, CONTINUOUS_OPTION_DEF.keys(),collect_cont_op, False)
print collect_cont_op.columns
print min(collect_cont_op.index), max(collect_cont_op.index)
collect_cont_op.head()
# Out:
# Index([u'SPXC.SERIESC-I3', u'SPXC.SERIESC-O1', u'SPXC.SERIESC-O3',
#        u'SPXC.SERIESC-O6', u'SPXC.SERIESC-OI', u'SPXC.SERIESC-ON',
#        u'SPXC.SERIESC-OY', u'SPXC.SERIESC-VI', u'SPXC.SERIESC-VM',
#        u'SPXC.SERIESP-I3', u'SPXC.SERIESP-O1', u'SPXC.SERIESP-O3',
#        u'SPXC.SERIESP-O6', u'SPXC.SERIESP-OI', u'SPXC.SERIESP-ON',
#        u'SPXC.SERIESP-OY', u'SPXC.SERIESP-VI', u'SPXC.SERIESP-VM',
#        u'VIXC.SERIESC-O1', u'VIXC.SERIESC-O3', u'VIXC.SERIESC-O6',
#        u'VIXC.SERIESC-OI', u'VIXC.SERIESC-ON', u'VIXC.SERIESC-OY',
#        u'VIXC.SERIESC-VI', u'VIXC.SERIESC-VM', u'VIXC.SERIESP-O1',
#        u'VIXC.SERIESP-O3', u'VIXC.SERIESP-O6', u'VIXC.SERIESP-OI',
#        u'VIXC.SERIESP-ON', u'VIXC.SERIESP-OY', u'VIXC.SERIESP-VI',
#        u'VIXC.SERIESP-VM'],
#       dtype='object')
# 2008-06-18 00:00:00 2014-12-31 00:00:00
#             SPXC.SERIESC-I3  SPXC.SERIESC-O1  SPXC.SERIESC-O3  \
# Date
# 2008-06-18           0.2380           0.2134           0.2157
# 2008-06-19           0.2378           0.2048           0.2058
# 2008-06-20           0.2418           0.2200           0.2150
# 2008-06-23           0.2421           0.2170           0.2163
# 2008-06-24           0.2316           0.2169           0.2199
#
#             SPXC.SERIESC-O6  SPXC.SERIESC-OI  SPXC.SERIESC-ON  \
# Date
# 2008-06-18           0.2177        4948198.0           0.2197
# 2008-06-19           0.2091        3060315.0           0.2162
# 2008-06-20           0.2187        3182287.0           0.2182
# 2008-06-23           0.2184        3222473.0           0.2186
# 2008-06-24           0.2174        3391221.0           0.2246
#
#             SPXC.SERIESC-OY  SPXC.SERIESC-VI  SPXC.SERIESC-VM  \
# Date
# 2008-06-18           0.2196          0.21301         359821.0
# 2008-06-19           0.2146          0.20559         396296.0
# 2008-06-20           0.2187          0.21879         256337.0
# 2008-06-23           0.2204          0.21153         187398.0
# 2008-06-24           0.1531          0.21630         248667.0
#
#             SPXC.SERIESP-I3  ...  VIXC.SERIESC-VI  VIXC.SERIESC-VM  \
# Date                         ...
# 2008-06-18           0.2385  ...              NaN              NaN
# 2008-06-19           0.2370  ...              NaN              NaN
# 2008-06-20           0.2372  ...              NaN              NaN
# 2008-06-23           0.2347  ...              NaN              NaN
# 2008-06-24           0.2369  ...              NaN              NaN
#
#             VIXC.SERIESP-O1  VIXC.SERIESP-O3  VIXC.SERIESP-O6  \
# Date
# 2008-06-18              NaN              NaN              NaN
# 2008-06-19              NaN              NaN              NaN
# 2008-06-20              NaN              NaN              NaN
# 2008-06-23              NaN              NaN              NaN
# 2008-06-24              NaN              NaN              NaN
#
#             VIXC.SERIESP-OI  VIXC.SERIESP-ON  VIXC.SERIESP-OY  \
# Date
# 2008-06-18              NaN              NaN              NaN
# 2008-06-19              NaN              NaN              NaN
# 2008-06-20              NaN              NaN              NaN
# 2008-06-23              NaN              NaN              NaN
# 2008-06-24              NaN              NaN              NaN
#
#             VIXC.SERIESP-VI  VIXC.SERIESP-VM
# Date
# 2008-06-18              NaN              NaN
# 2008-06-19              NaN              NaN
# 2008-06-20              NaN              NaN
# 2008-06-23              NaN              NaN
# 2008-06-24              NaN              NaN
#
# [5 rows x 34 columns]

# %%
# Process Futures
list_isin = ['CNI0307.txt', 'CNI0308.txt']
variable_isin = FUT_DEF.keys()

collect_fut = collection(['Data-snapshot','Futures'],
           ['Data-processed'],
           list_isin, FUT_DEF.keys())
variable_isin = FUT_DEF.keys()
#print collect
collect_fut = collection(['Data-snapshot','Futures'],
           ['Data-processed'],
           list_isin, FUT_DEF.keys(),collect_fut, False)
print collect_fut.columns
print min(collect_fut.index), max(collect_fut.index)
# Out:
# Index([u'CNI0307-PH', u'CNI0307-PL', u'CNI0307-PO', u'CNI0307-PS',
#        u'CNI0307-VM', u'CNI0308-PH', u'CNI0308-PL', u'CNI0308-PO',
#        u'CNI0308-PS', u'CNI0308-VM'],
#       dtype='object')
# 2006-09-12 00:00:00 2007-03-15 00:00:00

# %%
# Process Economic
list_isin = ['USNAPMNO.txt']
variable_isin = ECO_DEF.keys()

collect_eco = collection(['Data-snapshot','Economic'],
           ['Data-processed'],
           list_isin, ECO_DEF.keys())
variable_isin = ECO_DEF.keys()
#print collect
collect_eco = collection(['Data-snapshot','Economic'],
           ['Data-processed'],
           list_isin, ECO_DEF.keys(),collect_eco, False)
print collect_eco.columns
print min(collect_eco.index), max(collect_eco.index)
# Out:
# Index([u'USNAPMNO-ES'], dtype='object')
# 2005-01-15 00:00:00 2014-12-15 00:00:00

# %%
# Process Economic Poll 
list_isin = ['USUMINM1R.txt']
variable_isin = ECO_DEF.keys()

collect_eco = collection(['Data-snapshot','Economic Poll'],
           ['Data-processed'],
           list_isin, ECO_DEF.keys())
variable_isin = ECO_DEF.keys()
#print collect
collect_eco = collection(['Data-snapshot','Economic Poll'],
           ['Data-processed'],
           list_isin, ECO_DEF.keys(),collect_eco, False)
print collect_eco.columns
print min(collect_eco.index), max(collect_eco.index)
# Out:
# Index([u'USUMINM1R-ES'], dtype='object')
# 2005-01-15 00:00:00 2014-12-15 00:00:00

# %%
# Process Interest Rates
list_isin = ['EU18M2Y.txt']
variable_isin = IR_DEF.keys()

collect_ir = collection(['Data-snapshot','Interest Rates'],
           ['Data-processed'],
           list_isin, IR_DEF.keys())
variable_isin = IR_DEF.keys()
#print collect
collect_ir = collection(['Data-snapshot','Interest Rates'],
           ['Data-processed'],
           list_isin, IR_DEF.keys(),collect_ir, False)
print collect_ir.columns
print min(collect_ir.index), max(collect_ir.index)
# Out:
# Index([u'EU18M2Y-IR'], dtype='object')
# 2005-01-03 00:00:00 2014-12-31 00:00:00

# %%
# Process Static All.

# Comment: make a dataframe for each where the 

# Collect the list of a type of Data and append it to a dataframe. 
def process_s_df(path, filename, variable_isin):
#     print "Process df filename", filename
#     print "Process df path", path
#     print "Process df variable isin", variable_isin
    test = pd.read_csv(os.path.join(path,filename), sep=";",
                       header=0,infer_datetime_format=True,  encoding="utf-8")
    Col = list(test.columns)
    listcode = list(variable_isin)
    test.drop(set(test.columns).difference(set(listcode)),axis=1, inplace=True) 
    #test.set_index('NAME', inplace=True)
    #print "Process df test index with Date and cleaned", test.index
    return test

def collection_s(path_in, path_out, list_isin, variable_isin, cumul_df=None, first_df=True):
    source_path = os.path.join(os.getcwd(),*path_in)
    target_path = os.path.join(os.getcwd(),*path_out)
    for position,filename in enumerate(list_isin):
#         print "Collection Source path", source_path
#         print "Collection filename", filename
#         print "Collection variable isin",variable_isin
        code_to_keep = variable_isin  # To avoid append "Date" at each computation
        if first_df:
            return process_s_df(source_path, filename, variable_isin)
        if position > 0:
            print process_s_df(source_path, filename, variable_isin)
            cumul_df = pd.concat([cumul_df, process_s_df(source_path, filename, variable_isin)],axis=0)
    return cumul_df

# %%
# Process the equity Static information. 
list_isin = ['PA1436583006.txt', 'US4581401001.txt', 'US22160K1051.txt', 'US92343E1029.txt', 'AN8068571086.txt']
variable_isin = EQUITY_STATIC.keys()

collect_s_eq = collection_s(['Data-snapshot','US Stocks Static'],
           ['Data-processed'],
           list_isin, EQUITY_STATIC.keys())
variable_isin = EQUITY_STATIC.keys()
#print collect_s_eq
collect_s_eq = collection_s(['Data-snapshot','US Stocks Static'],
           ['Data-processed'],
           list_isin, EQUITY_STATIC.keys(),collect_s_eq, False)

collect_s_eq
# Out:
#            ISIN   NAME
# 0  US4581401001  INTEL
#            ISIN              NAME
# 0  US22160K1051  COSTCO WHOLESALE
#            ISIN      NAME
# 0  US92343E1029  VERISIGN
#            ISIN          NAME
# 0  AN8068571086  SCHLUMBERGER
#            ISIN              NAME
# 0  PA1436583006          CARNIVAL
# 0  US4581401001             INTEL
# 0  US22160K1051  COSTCO WHOLESALE
# 0  US92343E1029          VERISIGN
# 0  AN8068571086      SCHLUMBERGER

# %%
# Process the indicies - No information has been downloaded

# %%
# Process the Commodities
list_isin = ['GOLDBLN.txt', 'OILBREN.txt', 'OILWTXI.txt', 'SILVUSL.txt']
variable_isin = COMMO_STATIC.keys()

collect_s_como = collection_s(['Data-snapshot','Commodities Static'],
           ['Data-processed'],
           list_isin, COMMO_STATIC.keys())
variable_isin = COMMO_STATIC.keys()
#print collect_s_como
collect_s_como = collection_s(['Data-snapshot','Commodities Static'],
           ['Data-processed'],
           list_isin, COMMO_STATIC.keys(),collect_s_como, False)

collect_s_como
# Out:
#       MNEM                                   NAME
# 0  OILBREN  Crude Oil-Brent Cur. Month FOB U$/BBL
#       MNEM                                 NAME
# 0  OILWTXI  Crude Oil-WTI Near Month FOB U$/BBL
#       MNEM                           NAME
# 0  SILVUSL  LBMA Silver Price USD/Troy Oz
#       MNEM                                   NAME
# 0  GOLDBLN         Gold Bullion LBM U$/Troy Ounce
# 0  OILBREN  Crude Oil-Brent Cur. Month FOB U$/BBL
# 0  OILWTXI    Crude Oil-WTI Near Month FOB U$/BBL
# 0  SILVUSL          LBMA Silver Price USD/Troy Oz

# %%
# Process the Exchange Rates
list_isin = ['JAPAYE$.txt', 'USDOLSF.txt']
variable_isin = FX_STATIC.keys()

collect_s_fx = collection_s(['Data-snapshot','FX Static'],
           ['Data-processed'],
           list_isin, FX_STATIC.keys())
variable_isin = FX_STATIC.keys()
#print collect_s_fx
collect_s_fx = collection_s(['Data-snapshot','FX Static'],
           ['Data-processed'],
           list_isin, FX_STATIC.keys(),collect_s_fx, False)

collect_s_fx
# Out:
#       MNEM               NAME SICUR
# 0  USDOLSF  US $ TO CHF (WMR)    SF
#       MNEM                        NAME SICUR
# 0  JAPAYE$  JAPANESE YEN TO US $ (WMR)    U$
# 0  USDOLSF           US $ TO CHF (WMR)    SF

# %%
# Process the Options
list_isin = ['SPX04101255P.txt', 'SPX04101260P.txt']
variable_isin = OP_STATIC.keys()

collect_s_op = collection_s(['Data-snapshot','Options Index Static'],
           ['Data-processed'],
           list_isin, OP_STATIC.keys())
variable_isin = OP_STATIC.keys()
#print collect_s_op
collect_s_op = collection_s(['Data-snapshot','Options Index Static'],
           ['Data-processed'],
           list_isin, OP_STATIC.keys(),collect_s_op, False)

collect_s_op
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-66-31f189bfb4bd> in <module>()
#       5 collect_s_op = collection_s(['Data-snapshot','Options Index Static'],
#       6            ['Data-processed'],
# ----> 7            list_isin, OP_STATIC.keys())
#       8 variable_isin = OP_STATIC.keys()
#       9 #print collect_s_op
#
# <ipython-input-61-ef5b700e3cb6> in collection_s(path_in, path_out, list_isin, variable_isin, cumul_df, first_df)
#      26         code_to_keep = variable_isin  # To avoid append "Date" at each computation
#      27         if first_df:
# ---> 28             return process_s_df(source_path, filename, variable_isin)
#      29         if position > 0:
#      30             print process_s_df(source_path, filename, variable_isin)
#
# <ipython-input-61-ef5b700e3cb6> in process_s_df(path, filename, variable_isin)
#       9 #     print "Process df variable isin", variable_isin
#      10     test = pd.read_csv(os.path.join(path,filename), sep=";",
# ---> 11                        header=0,infer_datetime_format=True,  encoding="utf-8")
#      12     Col = list(test.columns)
#      13     listcode = list(variable_isin)
#
# /Users/pierrenowicki/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /Users/pierrenowicki/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /Users/pierrenowicki/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /Users/pierrenowicki/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /Users/pierrenowicki/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# IOError: [Errno 2] File /Users/pierrenowicki/Documents/PDF/Delete/Project/cs230-project/Data-snapshot/Options Index Static/SPX04101255P.txt does not exist: '/Users/pierrenowicki/Documents/PDF/Delete/Project/cs230-project/Data-snapshot/Options Index Static/SPX04101255P.txt'

# %%
# Process Futures
list_isin = ['CNI0307.txt', 'CNI0308.txt']
variable_isin = FUT_STATIC.keys()

collect_s_fut = collection_s(['Data-snapshot','Futures Static'],
           ['Data-processed'],
           list_isin, FUT_STATIC.keys())
variable_isin = FUT_STATIC.keys()
#print collect_s_fut
collect_s_fut = collection_s(['Data-snapshot','Futures Static'],
           ['Data-processed'],
           list_isin, FUT_STATIC.keys(),collect_s_fut, False)

collect_s_fut
# Out:
#        FUI    FUTBDATE     MNEM                           NAME        STDT
# 0  NASA100  2007-06-15  CNI0308  CME-NASDAQ 100 INDEX MAR 2008  2008-03-21
#        FUI    FUTBDATE     MNEM                           NAME        STDT
# 0  NASA100  2006-06-16  CNI0307  CME-NASDAQ 100 INDEX MAR 2007  2007-03-19
# 0  NASA100  2007-06-15  CNI0308  CME-NASDAQ 100 INDEX MAR 2008  2008-03-21

# %%
# Process Economic
list_isin = ['USNAPMNO.txt']
variable_isin = ECO_STATIC.keys()

collect_s_eco = collection_s(['Data-snapshot','Economic Static'],
           ['Data-processed'],
           list_isin, ECO_STATIC.keys())
variable_isin = ECO_STATIC.keys()
#print collect_s_eco
collect_s_eco = collection_s(['Data-snapshot','Economic Static'],
           ['Data-processed'],
           list_isin, ECO_STATIC.keys(),collect_s_eco, False)

collect_s_eco
# Out:
#        MNEM                                               NAME
# 0  USNAPMNO  US ISM MANUFACTURERS SURVEY: NEW ORDERS INDEX ...

# %%
# Process Interest Rates
list_isin = ['EU18M2Y.txt']
variable_isin = IR_STATIC.keys()

collect_s_ir = collection_s(['Data-snapshot','Interest Rates Static'],
           ['Data-processed'],
           list_isin, IR_STATIC.keys())
variable_isin = IR_STATIC.keys()
#print collect_s_ir
collect_s_ir = collection_s(['Data-snapshot','Interest Rates Static'],
           ['Data-processed'],
           list_isin, IR_STATIC.keys(),collect_s_ir, False)

collect_s_ir
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-69-143c6e2d17af> in <module>()
#       5 collect_s_ir = collection_s(['Data-snapshot','Interest Rates Static'],
#       6            ['Data-processed'],
# ----> 7            list_isin, IR_STATIC.keys())
#       8 variable_isin = IR_STATIC.keys()
#       9 #print collect_s_ir
#
# <ipython-input-61-ef5b700e3cb6> in collection_s(path_in, path_out, list_isin, variable_isin, cumul_df, first_df)
#      26         code_to_keep = variable_isin  # To avoid append "Date" at each computation
#      27         if first_df:
# ---> 28             return process_s_df(source_path, filename, variable_isin)
#      29         if position > 0:
#      30             print process_s_df(source_path, filename, variable_isin)
#
# <ipython-input-61-ef5b700e3cb6> in process_s_df(path, filename, variable_isin)
#       9 #     print "Process df variable isin", variable_isin
#      10     test = pd.read_csv(os.path.join(path,filename), sep=";",
# ---> 11                        header=0,infer_datetime_format=True,  encoding="utf-8")
#      12     Col = list(test.columns)
#      13     listcode = list(variable_isin)
#
# /Users/pierrenowicki/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /Users/pierrenowicki/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /Users/pierrenowicki/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /Users/pierrenowicki/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /Users/pierrenowicki/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# IOError: [Errno 2] File /Users/pierrenowicki/Documents/PDF/Delete/Project/cs230-project/Data-snapshot/Interest Rates Static/EU18M2Y.txt does not exist: '/Users/pierrenowicki/Documents/PDF/Delete/Project/cs230-project/Data-snapshot/Interest Rates Static/EU18M2Y.txt'

# %%
# Build a notebook for computation of classic factor.

# %%
# Collect the market information
source_path = os.path.join(os.getcwd(),'Data-snapshot','Commodities')
target_path = os.path.join(os.getcwd(),'Data-processed')
for filename in os.listdir(source_path):
    if filename.endswith(".txt"):
        test = pd.read_csv(os.path.join(source_path,filename), sep=";",
            header=0,parse_dates=[0],infer_datetime_format=True,  encoding="utf-8")
        print test
# Out:
#          SILVUSL       P
# 0     1968-04-01   2.259
# 1     1968-04-02   2.202
# 2     1968-04-03   2.195
# 3     1968-04-04   2.125
# 4     1968-04-05   2.104
# 5     1968-04-08   2.134
# 6     1968-04-09   2.205
# 7     1968-04-10   2.203
# 8     1968-04-11   2.161
# 9     1968-04-12   2.161
# 10    1968-04-15   2.161
# 11    1968-04-16   2.253
# 12    1968-04-17   2.303
# 13    1968-04-18   2.232
# 14    1968-04-19   2.281
# 15    1968-04-22   2.360
# 16    1968-04-23   2.360
# 17    1968-04-24   2.299
# 18    1968-04-25   2.308
# 19    1968-04-26   2.327
# 20    1968-04-29   2.396
# 21    1968-04-30   2.397
# 22    1968-05-01   2.357
# 23    1968-05-02   2.297
# 24    1968-05-03   2.315
# 25    1968-05-06   2.335
# 26    1968-05-07   2.245
# 27    1968-05-08   2.321
# 28    1968-05-09   2.319
# 29    1968-05-10   2.361
# ...          ...     ...
# 12495 2016-02-22  15.000
# 12496 2016-02-23  15.210
# 12497 2016-02-24  15.320
# 12498 2016-02-25  15.160
# 12499 2016-02-26  15.170
# 12500 2016-02-29  14.750
# 12501 2016-03-01  14.990
# 12502 2016-03-02  14.820
# 12503 2016-03-03  14.970
# 12504 2016-03-04  15.430
# 12505 2016-03-07  15.660
# 12506 2016-03-08  15.660
# 12507 2016-03-09  15.270
# 12508 2016-03-10  15.270
# 12509 2016-03-11  15.500
# 12510 2016-03-14  15.600
# 12511 2016-03-15  15.320
# 12512 2016-03-16  15.290
# 12513 2016-03-17  15.730
# 12514 2016-03-18  15.940
# 12515 2016-03-21  15.810
# 12516 2016-03-22  15.890
